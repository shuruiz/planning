# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:



import numpy as np 
import pandas as pd 
import warnings 
warnings.filterwarnings("ignore")
import tensorflow as tf 


print(tf.__version__)

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Bidirectional
from tensorflow.keras.layers import GRU
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import TimeDistributed
from tensorflow.keras.layers import RepeatVector
from tensorflow.keras import Input
from tensorflow.keras.layers import Flatten, Reshape
from tensorflow.keras import Model
from tensorflow.keras.layers import Conv2D,concatenate
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dropout
from attention import Attention_Block
# from attention import attention_block
from tensorflow.keras.layers import Attention
from step_attention import AttentionAugmentation2D, _normalize_depth_vars
# from keras.models import load_model

# In[2]:


# from google.colab import drive
# drive.mount('/content/drive')



# In[3]:


from loss import discounted_l1, max_displacement_error,v3_displacement_error
import math
import pickle5 as pickle
import matplotlib.pyplot as plt
from numpy import array
# import horovod.tensorflow.keras as hvd
# Out:
# 2.2.0

# %%
# hvd.init()

# In[4]:

import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]="1"


gpus = tf.config.experimental.list_logical_devices('GPU')
print(gpus)


if gpus:
    
    try:
        
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu,True)
    except:
        print('checking gpu error')
print('checking GPUs')


from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
config=tf.compat.v1.ConfigProto()
# config.gpu_options.visible_device_list= '0,1'
config.gpu_options.allow_growth=True

config.log_device_placement=True
# config.visible_device_list =2
sess=tf.compat.v1.Session(config=config)

tf.compat.v1.keras.backend.set_session(sess)


# In[5]:


from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras import initializers
import tensorflow.keras.backend as K
from sklearn.model_selection import train_test_split

from load_data import load_data
import os
# Out:
# [LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# checking gpu error
# checking GPUs
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: TITAN X (Pascal), pci bus id: 0000:06:00.0, compute capability: 6.1

# %%
# train_X_route = '/home/lab1/repo/lyft/newarray/training_features_vehicle.npy'
# # test_route = home+'/repo/data/X_to_val.npy'

# train_y_route = '/home/lab1/repo/lyft/newarray/training_labels_vehicle.npy'
# test_y_route = home+'/repo/data/y_to_val.npy'
prefix ='/home/lab1/repo/planning/traj_pred/data/'
train_raw, test_raw=None, None
for i in range(3):
    name_tr= prefix+'veh_train_set_'+str(i)+'.npy'
    name_te= prefix+'veh_test_set_'+str(i)+'.npy'
    tr = np.load(name_tr,allow_pickle=True).astype(float)
    te = np.load(name_te,allow_pickle=True).astype(float)
    if train_raw is None:
        train_raw=tr
    else:
        train_raw= np.vstack((train_raw, tr))
    
    if test_raw is None:
        test_raw=te
    else:
        test_raw= np.vstack((test_raw, te))

print(train_raw.shape, test_raw.shape)
# Out:
# (6121230, 11, 4) (153031, 20, 4)

# %%
np.random.shuffle(train_raw)
np.random.shuffle(test_raw)
max_n=300000
test_maxn=int(max_n*0.4)
train_set = train_raw[:max_n]
X_train=train_set[:,:10,2:4]
y_train=train_set[:,10,2:4]

test_set = test_raw[:test_maxn]
X_test=test_set[:,:10,2:4]
y_test=test_set[:,10,2:4]
y = test_set[:,10:,2:4]

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape, y.shape)
# Out:
# (300000, 10, 2) (300000, 2) (120000, 10, 2) (120000, 2) (120000, 10, 2)

# %%
# print(X_position.shape, y.shape, X.shape)
print(X_train.shape, y_train.shape)
print(y_train[0])
# Out:
# (300000, 10, 2) (300000, 2)
# [-43.47506714  47.15792847]

# %%
from sklearn.utils import shuffle

n_test=int(len(X_test)*0.5)
X_val, X_test, y_val, y_test= \
X_test[:n_test], X_test[n_test:], y_test[:n_test], y_test[n_test:]
y=test_set[:n_test,10:,2:4]


print(X_val.shape, y_val.shape)
# Out:
# (60000, 10, 2) (60000, 2)

# %%
# X_val=np.load("c_xval.npy")
# y_val=np.load('c_yval.npy')
# X_train=np.load("c_xtrain.npy")
# y_train=np.load("c_ytrain.npy")
# X_test=np.load("c_xtest.npy")
# y_test=np.load("c_ytest.npy")
from pathlib import Path
home = str(Path.home())

# %%
# In[9]:


filters=20
kernel_size = (3,3)
strides = (1,1)
depth_k =0.2
depth_v =0.2

channel_axis = 1 if K.image_data_format() == 'channels_first' else -1
print("before normalized k, v",depth_k,depth_k,strides)
depth_k, depth_v = _normalize_depth_vars(depth_k, depth_v, filters)
print("after normalized k, v",depth_k,depth_k,strides)


# In[10]:
time_step=10
tf.compat.v1.disable_eager_execution()

rnn = Sequential()
rnn.add(LSTM(128, return_sequences=True, kernel_regularizer='l1', input_shape=(time_step,2)))
rnn.add(LSTM(256, return_sequences=True, kernel_regularizer='l1',input_shape=(time_step,128)))
rnn.add(Reshape((time_step,16,16,1)))
rnn.summary()



cnn = Sequential()

cnn.add(Conv2D(1024, (4, 4),input_shape=(16, 16, 1)))
cnn.add(Conv2D(512, (2, 2)))
cnn.add(Conv2D(256, (4, 4)))
cnn.add(Conv2D(128, (2, 2)))
cnn.add(MaxPooling2D(2,2))
cnn.add(Conv2D(64, (2, 2)))
cnn.add(Conv2D(32, (2, 2)))
cnn.add(Conv2D(16, (2, 2)))

#attention block below
cnn.add(Conv2D(2 * depth_k + depth_k, (1, 1), strides))
cnn.add(AttentionAugmentation2D(depth_k, depth_v, num_heads=4, relative=True))

# cnn.add(Dropout(0.5))
cnn.add(Flatten())

 
cnn.add(Dense(128))
cnn.add(Dense(32))

cnn.summary() 



rnn2=Sequential()
rnn2.add(GRU(256, input_shape=(time_step,32)))


dense = Sequential()
dense.add(Dense(128))
dense.add(Dense(64))
dense.add(Dense(2)) # Model output

main_input = Input(shape=(time_step,2)) 
model = rnn(main_input)
model = TimeDistributed(cnn)(model) 
 # combine timedistributed cnn, attention, and fully connected network with rnn
model = rnn2(model)
model = dense(model) # add dense
final_model = Model(inputs=main_input, outputs=model)
final_model.summary()
# Out:
# before normalized k, v 0.2 0.2 (1, 1)
# after normalized k, v 4 4 (1, 1)
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:From /home/lab1/miniconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 128)           67072
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 256)           394240
# _________________________________________________________________
# reshape (Reshape)            (None, 10, 16, 16, 1)     0
# =================================================================
# Total params: 461,312
# Trainable params: 461,312
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 13, 13, 1024)      17408
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 12, 12, 512)       2097664
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 9, 256)         2097408
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 128)         131200
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 3, 3, 64)          32832
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 2, 2, 32)          8224
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 1, 1, 16)          2064
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 1, 1, 12)          204
# _________________________________________________________________
# attention_augmentation2d (At (None, 1, 1, 4)           2
# _________________________________________________________________
# flatten (Flatten)            (None, 4)                 0
# _________________________________________________________________
# dense (Dense)                (None, 128)               640
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                4128
# =================================================================
# Total params: 4,391,774
# Trainable params: 4,391,774
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Layer gru will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 10, 2)]           0
# _________________________________________________________________
# sequential (Sequential)      (None, 10, 16, 16, 1)     461312
# _________________________________________________________________
# time_distributed (TimeDistri (None, 10, 32)            4391774
# _________________________________________________________________
# sequential_2 (Sequential)    (None, 256)               222720
# _________________________________________________________________
# sequential_3 (Sequential)    (None, 2)                 41282
# =================================================================
# Total params: 5,117,088
# Trainable params: 5,117,088
# Non-trainable params: 0
# _________________________________________________________________

# %%
# print(home)

# %%
n_batch = 32
n_epoch  = 150


checkpoint_path =home+ "/repo/planning/traj_pred/veh_models/veh_{epoch}.h5"
checkpoint_dir = os.path.dirname(checkpoint_path)


# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_best_only=True,
                                                 save_weights_only=True,
                                                 verbose=1)


 #(None, n_steps, n_features)

sgd = tf.keras.optimizers.SGD(learning_rate=0.1, momentum=0.5, nesterov=True)
rmsprop =tf.keras.optimizers.RMSprop(learning_rate=0.001)



ftrl = tf.keras.optimizers.Ftrl(learning_rate=0.01)


mtrc = [tf.keras.metrics.MeanAbsoluteError()]
# [tf.keras.metrics.CosineSimilarity(axis=1)]

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.1,
    decay_steps=10000,
    decay_rate=0.95)

adagrad = tf.keras.optimizers.Adagrad(learning_rate=lr_schedule)
adadelta = tf.keras.optimizers.Adadelta(learning_rate=lr_schedule)

# to use customized loss, choose from  discounted_l1 or max_displacement_error function as loss parameter 
final_model.compile(loss=v3_displacement_error, optimizer=adadelta, metrics=mtrc)
# final_model.load_weights('/home/lab1/repo/models/lyft_vehicles/vehicles2_16.h5')

history=final_model.fit(X_train, 
                        y_train, epochs=n_epoch, 
                        batch_size=n_batch, 
                        verbose=2, 
                        validation_data=(X_val, y_val),
                        callbacks=[cp_callback])
# Out:
# Train on 300000 samples, validate on 60000 samples
# Epoch 1/150
#
# Epoch 00001: val_loss improved from inf to 2.76426, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_1.h5
# 300000/300000 - 1498s - loss: 4.8598 - mean_absolute_error: 1.6450 - val_loss: 2.7643 - val_mean_absolute_error: 1.1349
# Epoch 2/150
#
# Epoch 00002: val_loss improved from 2.76426 to 1.58572, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_2.h5
# 300000/300000 - 1505s - loss: 2.0539 - mean_absolute_error: 0.7457 - val_loss: 1.5857 - val_mean_absolute_error: 0.4991
# Epoch 3/150
#
# Epoch 00003: val_loss improved from 1.58572 to 1.51989, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_3.h5
# 300000/300000 - 1504s - loss: 1.7252 - mean_absolute_error: 0.6264 - val_loss: 1.5199 - val_mean_absolute_error: 0.5063
# Epoch 4/150
#
# Epoch 00004: val_loss did not improve from 1.51989
# 300000/300000 - 1517s - loss: 1.5474 - mean_absolute_error: 0.5602 - val_loss: 1.6644 - val_mean_absolute_error: 0.6497
# Epoch 5/150
#
# Epoch 00005: val_loss improved from 1.51989 to 1.38640, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_5.h5
# 300000/300000 - 1508s - loss: 1.4253 - mean_absolute_error: 0.5116 - val_loss: 1.3864 - val_mean_absolute_error: 0.4869
# Epoch 6/150
#
# Epoch 00006: val_loss improved from 1.38640 to 1.35740, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_6.h5
# 300000/300000 - 1510s - loss: 1.3320 - mean_absolute_error: 0.4760 - val_loss: 1.3574 - val_mean_absolute_error: 0.5094
# Epoch 7/150
#
# Epoch 00007: val_loss improved from 1.35740 to 1.21068, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_7.h5
# 300000/300000 - 1515s - loss: 1.2543 - mean_absolute_error: 0.4478 - val_loss: 1.2107 - val_mean_absolute_error: 0.4201
# Epoch 8/150
#
# Epoch 00008: val_loss improved from 1.21068 to 1.13482, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8.h5
# 300000/300000 - 1519s - loss: 1.1853 - mean_absolute_error: 0.4231 - val_loss: 1.1348 - val_mean_absolute_error: 0.3976
# Epoch 9/150
#
# Epoch 00009: val_loss improved from 1.13482 to 1.11366, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_9.h5
# 300000/300000 - 1519s - loss: 1.1263 - mean_absolute_error: 0.4029 - val_loss: 1.1137 - val_mean_absolute_error: 0.3868
# Epoch 10/150
#
# Epoch 00010: val_loss did not improve from 1.11366
# 300000/300000 - 1514s - loss: 1.0703 - mean_absolute_error: 0.3833 - val_loss: 1.1790 - val_mean_absolute_error: 0.4656
# Epoch 11/150
#
# Epoch 00011: val_loss improved from 1.11366 to 1.00402, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_11.h5
# 300000/300000 - 1530s - loss: 1.0234 - mean_absolute_error: 0.3675 - val_loss: 1.0040 - val_mean_absolute_error: 0.3658
# Epoch 12/150
#
# Epoch 00012: val_loss improved from 1.00402 to 0.97726, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_12.h5
# 300000/300000 - 1522s - loss: 0.9802 - mean_absolute_error: 0.3531 - val_loss: 0.9773 - val_mean_absolute_error: 0.3580
# Epoch 13/150
#
# Epoch 00013: val_loss improved from 0.97726 to 0.90358, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_13.h5
# 300000/300000 - 1519s - loss: 0.9418 - mean_absolute_error: 0.3409 - val_loss: 0.9036 - val_mean_absolute_error: 0.3183
# Epoch 14/150
#
# Epoch 00014: val_loss improved from 0.90358 to 0.78805, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_14.h5
# 300000/300000 - 1526s - loss: 0.9067 - mean_absolute_error: 0.3296 - val_loss: 0.7880 - val_mean_absolute_error: 0.2570
# Epoch 15/150
#
# Epoch 00015: val_loss did not improve from 0.78805
# 300000/300000 - 1515s - loss: 0.8722 - mean_absolute_error: 0.3181 - val_loss: 0.8194 - val_mean_absolute_error: 0.2868
# Epoch 16/150
#
# Epoch 00016: val_loss did not improve from 0.78805
# 300000/300000 - 1510s - loss: 0.8406 - mean_absolute_error: 0.3079 - val_loss: 0.8301 - val_mean_absolute_error: 0.2980
# Epoch 17/150
#
# Epoch 00017: val_loss did not improve from 0.78805
# 300000/300000 - 1509s - loss: 0.8135 - mean_absolute_error: 0.3002 - val_loss: 0.8183 - val_mean_absolute_error: 0.3124
# Epoch 18/150
#
# Epoch 00018: val_loss did not improve from 0.78805
# 300000/300000 - 1518s - loss: 0.7853 - mean_absolute_error: 0.2912 - val_loss: 0.8977 - val_mean_absolute_error: 0.3703
# Epoch 19/150
#
# Epoch 00019: val_loss improved from 0.78805 to 0.73696, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_19.h5
# 300000/300000 - 1516s - loss: 0.7606 - mean_absolute_error: 0.2842 - val_loss: 0.7370 - val_mean_absolute_error: 0.2696
# Epoch 20/150
#
# Epoch 00020: val_loss improved from 0.73696 to 0.71207, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_20.h5
# 300000/300000 - 1512s - loss: 0.7360 - mean_absolute_error: 0.2765 - val_loss: 0.7121 - val_mean_absolute_error: 0.2652
# Epoch 21/150
#
# Epoch 00021: val_loss improved from 0.71207 to 0.64848, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_21.h5
# 300000/300000 - 1516s - loss: 0.7140 - mean_absolute_error: 0.2701 - val_loss: 0.6485 - val_mean_absolute_error: 0.2318
# Epoch 22/150
#
# Epoch 00022: val_loss did not improve from 0.64848
# 300000/300000 - 1526s - loss: 0.6941 - mean_absolute_error: 0.2647 - val_loss: 0.6734 - val_mean_absolute_error: 0.2510
# Epoch 23/150
#
# Epoch 00023: val_loss improved from 0.64848 to 0.62369, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_23.h5
# 300000/300000 - 1528s - loss: 0.6744 - mean_absolute_error: 0.2588 - val_loss: 0.6237 - val_mean_absolute_error: 0.2296
# Epoch 24/150
#
# Epoch 00024: val_loss improved from 0.62369 to 0.61316, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_24.h5
# 300000/300000 - 1530s - loss: 0.6565 - mean_absolute_error: 0.2539 - val_loss: 0.6132 - val_mean_absolute_error: 0.2283
# Epoch 25/150
#
# Epoch 00025: val_loss did not improve from 0.61316
# 300000/300000 - 1530s - loss: 0.6397 - mean_absolute_error: 0.2493 - val_loss: 0.6332 - val_mean_absolute_error: 0.2453
# Epoch 26/150
#
# Epoch 00026: val_loss did not improve from 0.61316
# 300000/300000 - 1535s - loss: 0.6242 - mean_absolute_error: 0.2455 - val_loss: 0.6311 - val_mean_absolute_error: 0.2496
# Epoch 27/150
#
# Epoch 00027: val_loss improved from 0.61316 to 0.58974, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_27.h5
# 300000/300000 - 1538s - loss: 0.6072 - mean_absolute_error: 0.2401 - val_loss: 0.5897 - val_mean_absolute_error: 0.2330
# Epoch 28/150
#
# Epoch 00028: val_loss improved from 0.58974 to 0.56959, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_28.h5
# 300000/300000 - 1541s - loss: 0.5935 - mean_absolute_error: 0.2369 - val_loss: 0.5696 - val_mean_absolute_error: 0.2241
# Epoch 29/150
#
# Epoch 00029: val_loss did not improve from 0.56959
# 300000/300000 - 1547s - loss: 0.5794 - mean_absolute_error: 0.2332 - val_loss: 0.6438 - val_mean_absolute_error: 0.2829
# Epoch 30/150
#
# Epoch 00030: val_loss improved from 0.56959 to 0.56205, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_30.h5
# 300000/300000 - 1570s - loss: 0.5662 - mean_absolute_error: 0.2297 - val_loss: 0.5621 - val_mean_absolute_error: 0.2310
# Epoch 31/150
#
# Epoch 00031: val_loss improved from 0.56205 to 0.54703, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_31.h5
# 300000/300000 - 1561s - loss: 0.5541 - mean_absolute_error: 0.2265 - val_loss: 0.5470 - val_mean_absolute_error: 0.2249
# Epoch 32/150
#
# Epoch 00032: val_loss improved from 0.54703 to 0.53980, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_32.h5
# 300000/300000 - 1559s - loss: 0.5429 - mean_absolute_error: 0.2239 - val_loss: 0.5398 - val_mean_absolute_error: 0.2243
# Epoch 33/150
#
# Epoch 00033: val_loss improved from 0.53980 to 0.52601, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_33.h5
# 300000/300000 - 1557s - loss: 0.5316 - mean_absolute_error: 0.2211 - val_loss: 0.5260 - val_mean_absolute_error: 0.2164
# Epoch 34/150
#
# Epoch 00034: val_loss improved from 0.52601 to 0.51185, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_34.h5
# 300000/300000 - 1563s - loss: 0.5207 - mean_absolute_error: 0.2183 - val_loss: 0.5118 - val_mean_absolute_error: 0.2151
# Epoch 35/150
#
# Epoch 00035: val_loss improved from 0.51185 to 0.50447, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_35.h5
# 300000/300000 - 1588s - loss: 0.5111 - mean_absolute_error: 0.2160 - val_loss: 0.5045 - val_mean_absolute_error: 0.2136
# Epoch 36/150
#
# Epoch 00036: val_loss improved from 0.50447 to 0.50307, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_36.h5
# 300000/300000 - 1591s - loss: 0.5014 - mean_absolute_error: 0.2136 - val_loss: 0.5031 - val_mean_absolute_error: 0.2173
# Epoch 37/150
#
# Epoch 00037: val_loss improved from 0.50307 to 0.47892, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_37.h5
# 300000/300000 - 1590s - loss: 0.4924 - mean_absolute_error: 0.2114 - val_loss: 0.4789 - val_mean_absolute_error: 0.2041
# Epoch 38/150
#
# Epoch 00038: val_loss improved from 0.47892 to 0.46945, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_38.h5
# 300000/300000 - 1599s - loss: 0.4840 - mean_absolute_error: 0.2093 - val_loss: 0.4695 - val_mean_absolute_error: 0.1998
# Epoch 39/150
#
# Epoch 00039: val_loss improved from 0.46945 to 0.46476, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_39.h5
# 300000/300000 - 1628s - loss: 0.4761 - mean_absolute_error: 0.2075 - val_loss: 0.4648 - val_mean_absolute_error: 0.2008
# Epoch 40/150
#
# Epoch 00040: val_loss improved from 0.46476 to 0.45549, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_40.h5
# 300000/300000 - 1628s - loss: 0.4687 - mean_absolute_error: 0.2059 - val_loss: 0.4555 - val_mean_absolute_error: 0.1976
# Epoch 41/150
#
# Epoch 00041: val_loss did not improve from 0.45549
# 300000/300000 - 1599s - loss: 0.4613 - mean_absolute_error: 0.2041 - val_loss: 0.4564 - val_mean_absolute_error: 0.2032
# Epoch 42/150
#
# Epoch 00042: val_loss improved from 0.45549 to 0.43781, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_42.h5
# 300000/300000 - 1621s - loss: 0.4544 - mean_absolute_error: 0.2025 - val_loss: 0.4378 - val_mean_absolute_error: 0.1927
# Epoch 43/150
#
# Epoch 00043: val_loss improved from 0.43781 to 0.43557, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_43.h5
# 300000/300000 - 1607s - loss: 0.4478 - mean_absolute_error: 0.2010 - val_loss: 0.4356 - val_mean_absolute_error: 0.1944
# Epoch 44/150
#
# Epoch 00044: val_loss improved from 0.43557 to 0.43189, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_44.h5
# 300000/300000 - 1597s - loss: 0.4417 - mean_absolute_error: 0.1996 - val_loss: 0.4319 - val_mean_absolute_error: 0.1955
# Epoch 45/150
#
# Epoch 00045: val_loss improved from 0.43189 to 0.42382, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_45.h5
# 300000/300000 - 1626s - loss: 0.4361 - mean_absolute_error: 0.1985 - val_loss: 0.4238 - val_mean_absolute_error: 0.1924
# Epoch 46/150
#
# Epoch 00046: val_loss did not improve from 0.42382
# 300000/300000 - 1672s - loss: 0.4302 - mean_absolute_error: 0.1971 - val_loss: 0.4295 - val_mean_absolute_error: 0.1966
# Epoch 47/150
#
# Epoch 00047: val_loss improved from 0.42382 to 0.42232, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_47.h5
# 300000/300000 - 1629s - loss: 0.4246 - mean_absolute_error: 0.1957 - val_loss: 0.4223 - val_mean_absolute_error: 0.1961
# Epoch 48/150
#
# Epoch 00048: val_loss improved from 0.42232 to 0.41117, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_48.h5
# 300000/300000 - 1649s - loss: 0.4197 - mean_absolute_error: 0.1947 - val_loss: 0.4112 - val_mean_absolute_error: 0.1900
# Epoch 49/150
#
# Epoch 00049: val_loss did not improve from 0.41117
# 300000/300000 - 1648s - loss: 0.4150 - mean_absolute_error: 0.1938 - val_loss: 0.4180 - val_mean_absolute_error: 0.1969
# Epoch 50/150
#
# Epoch 00050: val_loss improved from 0.41117 to 0.39907, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_50.h5
# 300000/300000 - 1631s - loss: 0.4107 - mean_absolute_error: 0.1929 - val_loss: 0.3991 - val_mean_absolute_error: 0.1868
# Epoch 51/150
#
# Epoch 00051: val_loss did not improve from 0.39907
# 300000/300000 - 1631s - loss: 0.4061 - mean_absolute_error: 0.1918 - val_loss: 0.4108 - val_mean_absolute_error: 0.1949
# Epoch 52/150
#
# Epoch 00052: val_loss did not improve from 0.39907
# 300000/300000 - 1638s - loss: 0.4021 - mean_absolute_error: 0.1910 - val_loss: 0.4026 - val_mean_absolute_error: 0.1926
# Epoch 53/150
#
# Epoch 00053: val_loss improved from 0.39907 to 0.38873, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_53.h5
# 300000/300000 - 1636s - loss: 0.3981 - mean_absolute_error: 0.1901 - val_loss: 0.3887 - val_mean_absolute_error: 0.1846
# Epoch 54/150
#
# Epoch 00054: val_loss did not improve from 0.38873
# 300000/300000 - 1646s - loss: 0.3946 - mean_absolute_error: 0.1894 - val_loss: 0.3891 - val_mean_absolute_error: 0.1870
# Epoch 55/150
#
# Epoch 00055: val_loss improved from 0.38873 to 0.38726, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_55.h5
# 300000/300000 - 1666s - loss: 0.3913 - mean_absolute_error: 0.1889 - val_loss: 0.3873 - val_mean_absolute_error: 0.1867
# Epoch 56/150
#
# Epoch 00056: val_loss improved from 0.38726 to 0.38350, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_56.h5
# 300000/300000 - 1656s - loss: 0.3878 - mean_absolute_error: 0.1882 - val_loss: 0.3835 - val_mean_absolute_error: 0.1859
# Epoch 57/150
#
# Epoch 00057: val_loss improved from 0.38350 to 0.37889, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_57.h5
# 300000/300000 - 1668s - loss: 0.3844 - mean_absolute_error: 0.1873 - val_loss: 0.3789 - val_mean_absolute_error: 0.1841
# Epoch 58/150
#
# Epoch 00058: val_loss did not improve from 0.37889
# 300000/300000 - 1688s - loss: 0.3814 - mean_absolute_error: 0.1867 - val_loss: 0.3859 - val_mean_absolute_error: 0.1894
# Epoch 59/150
#
# Epoch 00059: val_loss did not improve from 0.37889
# 300000/300000 - 1679s - loss: 0.3787 - mean_absolute_error: 0.1863 - val_loss: 0.3825 - val_mean_absolute_error: 0.1894
# Epoch 60/150
#
# Epoch 00060: val_loss did not improve from 0.37889
# 300000/300000 - 1678s - loss: 0.3759 - mean_absolute_error: 0.1857 - val_loss: 0.3804 - val_mean_absolute_error: 0.1889
# Epoch 61/150
#
# Epoch 00061: val_loss improved from 0.37889 to 0.37249, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_61.h5
# 300000/300000 - 1684s - loss: 0.3732 - mean_absolute_error: 0.1851 - val_loss: 0.3725 - val_mean_absolute_error: 0.1854
# Epoch 62/150
#
# Epoch 00062: val_loss improved from 0.37249 to 0.36986, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_62.h5
# 300000/300000 - 1628s - loss: 0.3707 - mean_absolute_error: 0.1846 - val_loss: 0.3699 - val_mean_absolute_error: 0.1847
# Epoch 63/150
#
# Epoch 00063: val_loss improved from 0.36986 to 0.36398, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_63.h5
# 300000/300000 - 1613s - loss: 0.3683 - mean_absolute_error: 0.1840 - val_loss: 0.3640 - val_mean_absolute_error: 0.1818
# Epoch 64/150
#
# Epoch 00064: val_loss did not improve from 0.36398
# 300000/300000 - 1620s - loss: 0.3661 - mean_absolute_error: 0.1837 - val_loss: 0.3761 - val_mean_absolute_error: 0.1913
# Epoch 65/150
#
# Epoch 00065: val_loss did not improve from 0.36398
# 300000/300000 - 1623s - loss: 0.3639 - mean_absolute_error: 0.1832 - val_loss: 0.3664 - val_mean_absolute_error: 0.1854
# Epoch 66/150
#
# Epoch 00066: val_loss improved from 0.36398 to 0.36042, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_66.h5
# 300000/300000 - 1615s - loss: 0.3620 - mean_absolute_error: 0.1829 - val_loss: 0.3604 - val_mean_absolute_error: 0.1823
# Epoch 67/150
#
# Epoch 00067: val_loss did not improve from 0.36042
# 300000/300000 - 1620s - loss: 0.3600 - mean_absolute_error: 0.1825 - val_loss: 0.3646 - val_mean_absolute_error: 0.1858
# Epoch 68/150
#
# Epoch 00068: val_loss did not improve from 0.36042
# 300000/300000 - 1632s - loss: 0.3582 - mean_absolute_error: 0.1822 - val_loss: 0.3708 - val_mean_absolute_error: 0.1915
# Epoch 69/150
#
# Epoch 00069: val_loss improved from 0.36042 to 0.35352, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_69.h5
# 300000/300000 - 1623s - loss: 0.3564 - mean_absolute_error: 0.1818 - val_loss: 0.3535 - val_mean_absolute_error: 0.1804
# Epoch 70/150
#
# Epoch 00070: val_loss did not improve from 0.35352
# 300000/300000 - 1615s - loss: 0.3548 - mean_absolute_error: 0.1815 - val_loss: 0.3556 - val_mean_absolute_error: 0.1824
# Epoch 71/150
#
# Epoch 00071: val_loss did not improve from 0.35352
# 300000/300000 - 1654s - loss: 0.3532 - mean_absolute_error: 0.1812 - val_loss: 0.3609 - val_mean_absolute_error: 0.1870
# Epoch 72/150
#
# Epoch 00072: val_loss did not improve from 0.35352
# 300000/300000 - 1669s - loss: 0.3517 - mean_absolute_error: 0.1809 - val_loss: 0.3562 - val_mean_absolute_error: 0.1843
# Epoch 73/150
#
# Epoch 00073: val_loss did not improve from 0.35352
# 300000/300000 - 1694s - loss: 0.3503 - mean_absolute_error: 0.1806 - val_loss: 0.3539 - val_mean_absolute_error: 0.1836
# Epoch 74/150
#
# Epoch 00074: val_loss improved from 0.35352 to 0.34994, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_74.h5
# 300000/300000 - 1680s - loss: 0.3488 - mean_absolute_error: 0.1803 - val_loss: 0.3499 - val_mean_absolute_error: 0.1814
# Epoch 75/150
#
# Epoch 00075: val_loss improved from 0.34994 to 0.34943, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_75.h5
# 300000/300000 - 1691s - loss: 0.3476 - mean_absolute_error: 0.1801 - val_loss: 0.3494 - val_mean_absolute_error: 0.1818
# Epoch 76/150
#
# Epoch 00076: val_loss improved from 0.34943 to 0.34792, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_76.h5
# 300000/300000 - 1710s - loss: 0.3463 - mean_absolute_error: 0.1798 - val_loss: 0.3479 - val_mean_absolute_error: 0.1814
# Epoch 77/150
#
# Epoch 00077: val_loss improved from 0.34792 to 0.34690, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_77.h5
# 300000/300000 - 1711s - loss: 0.3451 - mean_absolute_error: 0.1796 - val_loss: 0.3469 - val_mean_absolute_error: 0.1812
# Epoch 78/150

# %%
print("Evaluate on test data")
results = final_model.evaluate(X_test, y_test, batch_size=32)
print("test loss, test acc:", results)


_history_path = home+ '/repo/planning/traj_pred/total_model_history/veh_history.sav'
pickle.dump(history.history, open(_history_path, 'wb'))

_weights_path =  home+ '/repo/planning/traj_pred/total_model_history/veh_weights.h5'
final_model.save_weights(_weights_path)

# %%
################################DONE

# %%
# In[ ]:
# X_val, X_test, y_val, y_test,X_train, , y_train, 
np.save("v_xval",X_val)
np.save('v_yval',y_val)
np.save("v_xtrain",X_train)
np.save("v_ytrain",y_train)
np.save("v_xtest",X_test)
np.save("v_ytest",y_test)
np.save("v_y",y)

# %%
history.history.keys()
ax1,=plt.plot( history.history['loss'], c='b', label='Training loss')
ax2,=plt.plot( history.history['val_loss'], c='r', label='Validation loss')

plt.legend(handles=[ax1])
plt.title('loss')
plt.show()

# %%
# final_model.compile(loss=v3_displacement_error, optimizer=adadelta, metrics=mtrc)
# final_model.load_weights('home+ '/repo/planning/traj_pred/total_model_history/veh_weights.h5'')

# %%
# ##prediction
# # from utilities import get_position_sequence
# def get_position_sequence(prev, new):
#     arr = np.delete(prev, 0, 0)
#     a=np.vstack((arr,new))
#     return a 

# def get_sequence_prediction(X_position_test, i):
#     results =[]
#     s=X_position_test[i]
#     for count in range(0,50):
        
#         result = final_model.predict(np.array([s]))
# #         print(result)
#         results.append(result[0])
#         s = get_position_sequence(s, result)
#     results=np.array(results)
# #     print(s.shape,results.shape)
    
#     return results

# # i= np.random.randint(0, len(X_test))
# # results = get_sequence_prediction(X_test, i)
# # print(results.shape)

# test=np.load('vehicle_test_history.npy')
# v_predict=[]
# print(len(test))
# for i in range(len(test)):
#     print(i)
#     results = get_sequence_prediction(test, i)
#     v_predict.append(results)
# np.save("v_predictions",v_predict)

# print('done')

# %%
# print(np.array(v_predict).shape)
# np.save("v_predictions",v_predict)
# print('done')

# %%
# i= np.random.randint(0, len(X_test))


# # In[ ]:
# # i =2273

# # i=1574
# # i=3070

# # i=387,39
# # i=667
# # i=15
# print("showing trip", i)


# # from utilities import get_position_sequence
# def get_position_sequence(prev, new):
#     arr = np.delete(prev, 0, 0)
#     a=np.vstack((arr,new))
#     return a 

# def get_sequence_prediction(X_position_test, i):
#     results =[]
#     s=X_position_test[i]
#     for count in range(0,12):
        
#         result = final_model.predict(np.array([s]))
# #         print(result)
#         results.append(result[0])
#         s = get_position_sequence(s, result)
#     results=np.array(results)
# #     print(s.shape,results.shape)
    
#     return results

# results = get_sequence_prediction(X_test, i)

# # print(len(results))
# # print("sss",results)

# ax1 =plt.scatter(y_test[i][:,0],y_test[i][:,1],color='b',label='Ground truth')

# ax2 =plt.scatter(X_test[i][:,0],X_test[i][:,1],color='r', label='Training segment')


# ax3 =plt.scatter(results[:,0],results[:,1],color='g', label='Prediction')
# # ax3 =plt.scatter(result[0][0],result[0][1],color='g', label='Prediction')

# plt.legend(handles=[ax1, ax2, ax3])
# plt.show()

# distance = v3_displacement_error(results,y_test[i] )
# avg = K.mean(distance)
# pl =[]
# # tf.print(distance,output_stream=sys.stderr)
# with tf.compat.v1.Session() as sess: pl=distance.eval(), print(distance.eval(),'\naverage',avg.eval()) 
# import matplotlib.pyplot as plt
# # print(pl[0])
# plt.plot(pl[0])
# plt.title('Displacement error')
# plt.show()

# %%
# final_displacement=[]
# avg_displacement=[]

# # for idx in range(0,len(X_test)):
# for idx in range(0,1000):
#     p=[]
#     re= get_sequence_prediction(X_test, idx)
#     distance = v3_displacement_error(re,y_test[idx] )
#     avg = K.mean(distance)
    
#     with tf.compat.v1.Session() as sess:
#         p=distance.eval()
#         ax =avg.eval()
# #     print(p,ax)
#     final_displacement.append(p)
#     avg_displacement.append(ax)

# final_displacement = np.array(final_displacement)
# sec=[]

# for j in range(0,final_displacement.shape[1]):
#     displacement = sum(final_displacement[:,j])/len(final_displacement)
    
#     sec.append(displacement)
# print("Final displacement error:",sec[-1])
# print("Average displacement error:",sum(avg_displacement)/len(avg_displacement))

# print(sec)
# plt.plot(sec)
# plt.title("average displacement error at each timestep")
# plt.show()

# %%
# history2 = pickle.load(open( cwd+ '/saved_model/lab1_txt_max_history_mae_adadelta_600.sav',  "rb") ) 
# history3 = pickle.load(open( cwd+ '/saved_model/lab1_txt_max_history_mae_adadelta.sav',  "rb") )
# print(len(history.history['loss']))
# # plt.plot(range(600,1100),history.history['loss'], c='b')
# # plt.plot( range(300,600), history2['loss'], c='b')
# plt.plot( history3['loss'], c='b')
# plt.title('train loss')

# # plt.plot(range(600,1100),history.history['val_loss'], c='r')
# # plt.plot( range(300,600), history2['val_loss'], c='r')
# plt.plot( history3['val_loss'], c='r')
# plt.title('loss')


# plt.show()
