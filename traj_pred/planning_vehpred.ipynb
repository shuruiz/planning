# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:



import numpy as np 
import pandas as pd 
import warnings 
warnings.filterwarnings("ignore")
import tensorflow as tf 


print(tf.__version__)

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Bidirectional
from tensorflow.keras.layers import GRU
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import TimeDistributed
from tensorflow.keras.layers import RepeatVector
from tensorflow.keras import Input
from tensorflow.keras.layers import Flatten, Reshape
from tensorflow.keras import Model
from tensorflow.keras.layers import Conv2D,concatenate
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dropout
from attention import Attention_Block
# from attention import attention_block
from tensorflow.keras.layers import Attention
from step_attention import AttentionAugmentation2D, _normalize_depth_vars
# from keras.models import load_model

# In[2]:


# from google.colab import drive
# drive.mount('/content/drive')



# In[3]:


from loss import discounted_l1, max_displacement_error,v3_displacement_error
import math
import pickle5 as pickle
import matplotlib.pyplot as plt
from numpy import array
# import horovod.tensorflow.keras as hvd
# Out:
# 2.2.0

# %%
# hvd.init()

# In[4]:

import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]="1"


gpus = tf.config.experimental.list_logical_devices('GPU')
print(gpus)


if gpus:
    
    try:
        
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu,True)
    except:
        print('checking gpu error')
print('checking GPUs')


from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
config=tf.compat.v1.ConfigProto()
# config.gpu_options.visible_device_list= '0,1'
config.gpu_options.allow_growth=True

config.log_device_placement=True
# config.visible_device_list =2
sess=tf.compat.v1.Session(config=config)

tf.compat.v1.keras.backend.set_session(sess)


# In[5]:


from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras import initializers
import tensorflow.keras.backend as K
from sklearn.model_selection import train_test_split

from load_data import load_data
import os
# Out:
# [LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# checking gpu error
# checking GPUs
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: TITAN X (Pascal), pci bus id: 0000:06:00.0, compute capability: 6.1

# %%
# train_X_route = '/home/lab1/repo/lyft/newarray/training_features_vehicle.npy'
# # test_route = home+'/repo/data/X_to_val.npy'

# train_y_route = '/home/lab1/repo/lyft/newarray/training_labels_vehicle.npy'
# test_y_route = home+'/repo/data/y_to_val.npy'
prefix ='/home/lab1/repo/planning/traj_pred/data/'
train_raw, test_raw=None, None
for i in range(3):
    name_tr= prefix+'veh_train_set_'+str(i)+'.npy'
    name_te= prefix+'veh_test_set_'+str(i)+'.npy'
    tr = np.load(name_tr,allow_pickle=True).astype(float)
    te = np.load(name_te,allow_pickle=True).astype(float)
    if train_raw is None:
        train_raw=tr
    else:
        train_raw= np.vstack((train_raw, tr))
    
    if test_raw is None:
        test_raw=te
    else:
        test_raw= np.vstack((test_raw, te))

print(train_raw.shape, test_raw.shape)
# Out:
# (6121230, 11, 4) (153031, 20, 4)

# %%
np.random.shuffle(train_raw)
np.random.shuffle(test_raw)
max_n=300000
test_maxn=int(max_n*0.4)
train_set = train_raw[:max_n]
X_train=train_set[:,:10,2:4]
y_train=train_set[:,10,2:4]

test_set = test_raw[:test_maxn]
X_test=test_set[:,:10,2:4]
y_test=test_set[:,10,2:4]
y = test_set[:,10:,2:4]

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape, y.shape)
# Out:
# (300000, 10, 2) (300000, 2) (120000, 10, 2) (120000, 2) (120000, 10, 2)

# %%
# print(X_position.shape, y.shape, X.shape)
print(X_train.shape, y_train.shape)
print(y_train[0])
# Out:
# (300000, 10, 2) (300000, 2)
# [-22.84960938  27.50488281]

# %%
from sklearn.utils import shuffle

n_test=int(len(X_test)*0.5)
X_val, X_test, y_val, y_test= \
X_test[:n_test], X_test[n_test:], y_test[:n_test], y_test[n_test:]
y=test_set[:n_test,10:,2:4]


print(X_val.shape, y_val.shape)
# Out:
# (60000, 10, 2) (60000, 2)

# %%
np.save("train_data/v_xval",X_val)
np.save('train_data/v_yval',y_val)
np.save("train_data/v_xtrain",X_train)
np.save("train_data/v_ytrain",y_train)
np.save("train_data/v_xtest",X_test)
np.save("train_data/v_ytest",y_test)
np.save("train_data/v_y",y) # y is the full gt trajectory of xtest, relative coordinate
np.save('train_data/v_test_xall',test_set[:n_test] ) # test set, including xtest and y as well as global coordinate

# %%
# X_val=np.load("c_xval.npy")
# y_val=np.load('c_yval.npy')
# X_train=np.load("c_xtrain.npy")
# y_train=np.load("c_ytrain.npy")
# X_test=np.load("c_xtest.npy")
# y_test=np.load("c_ytest.npy")
from pathlib import Path
home = str(Path.home())

# %%
# In[9]:


filters=20
kernel_size = (3,3)
strides = (1,1)
depth_k =0.2
depth_v =0.2

channel_axis = 1 if K.image_data_format() == 'channels_first' else -1
print("before normalized k, v",depth_k,depth_k,strides)
depth_k, depth_v = _normalize_depth_vars(depth_k, depth_v, filters)
print("after normalized k, v",depth_k,depth_k,strides)


# In[10]:
time_step=10
tf.compat.v1.disable_eager_execution()

rnn = Sequential()
rnn.add(LSTM(128, return_sequences=True, kernel_regularizer='l1', input_shape=(time_step,2)))
rnn.add(LSTM(256, return_sequences=True, kernel_regularizer='l1',input_shape=(time_step,128)))
rnn.add(Reshape((time_step,16,16,1)))
rnn.summary()



cnn = Sequential()

cnn.add(Conv2D(1024, (4, 4),input_shape=(16, 16, 1)))
cnn.add(Conv2D(512, (2, 2)))
cnn.add(Conv2D(256, (4, 4)))
cnn.add(Conv2D(128, (2, 2)))
cnn.add(MaxPooling2D(2,2))
cnn.add(Conv2D(64, (2, 2)))
cnn.add(Conv2D(32, (2, 2)))
cnn.add(Conv2D(16, (2, 2)))

#attention block below
cnn.add(Conv2D(2 * depth_k + depth_k, (1, 1), strides))
cnn.add(AttentionAugmentation2D(depth_k, depth_v, num_heads=4, relative=True))

# cnn.add(Dropout(0.5))
cnn.add(Flatten())

 
cnn.add(Dense(128))
cnn.add(Dense(32))

cnn.summary() 



rnn2=Sequential()
rnn2.add(GRU(256, input_shape=(time_step,32)))


dense = Sequential()
dense.add(Dense(128))
dense.add(Dense(64))
dense.add(Dense(2)) # Model output

main_input = Input(shape=(time_step,2)) 
model = rnn(main_input)
model = TimeDistributed(cnn)(model) 
 # combine timedistributed cnn, attention, and fully connected network with rnn
model = rnn2(model)
model = dense(model) # add dense
final_model = Model(inputs=main_input, outputs=model)
final_model.summary()
# Out:
# before normalized k, v 0.2 0.2 (1, 1)
# after normalized k, v 4 4 (1, 1)
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:From /home/lab1/miniconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 128)           67072
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 256)           394240
# _________________________________________________________________
# reshape (Reshape)            (None, 10, 16, 16, 1)     0
# =================================================================
# Total params: 461,312
# Trainable params: 461,312
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 13, 13, 1024)      17408
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 12, 12, 512)       2097664
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 9, 256)         2097408
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 128)         131200
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 3, 3, 64)          32832
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 2, 2, 32)          8224
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 1, 1, 16)          2064
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 1, 1, 12)          204
# _________________________________________________________________
# attention_augmentation2d (At (None, 1, 1, 4)           2
# _________________________________________________________________
# flatten (Flatten)            (None, 4)                 0
# _________________________________________________________________
# dense (Dense)                (None, 128)               640
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                4128
# =================================================================
# Total params: 4,391,774
# Trainable params: 4,391,774
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Layer gru will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 10, 2)]           0
# _________________________________________________________________
# sequential (Sequential)      (None, 10, 16, 16, 1)     461312
# _________________________________________________________________
# time_distributed (TimeDistri (None, 10, 32)            4391774
# _________________________________________________________________
# sequential_2 (Sequential)    (None, 256)               222720
# _________________________________________________________________
# sequential_3 (Sequential)    (None, 2)                 41282
# =================================================================
# Total params: 5,117,088
# Trainable params: 5,117,088
# Non-trainable params: 0
# _________________________________________________________________

# %%
# print(home)

# %%
n_batch = 32
n_epoch  = 50


checkpoint_path =home+ "/repo/planning/traj_pred/veh_models/veh_m.h5"
checkpoint_dir = os.path.dirname(checkpoint_path)


# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_best_only=True,
                                                 save_weights_only=True,
                                                 verbose=1)


 #(None, n_steps, n_features)

sgd = tf.keras.optimizers.SGD(learning_rate=0.1, momentum=0.5, nesterov=True)
rmsprop =tf.keras.optimizers.RMSprop(learning_rate=0.001)



ftrl = tf.keras.optimizers.Ftrl(learning_rate=0.01)


mtrc = [tf.keras.metrics.MeanAbsoluteError()]
# [tf.keras.metrics.CosineSimilarity(axis=1)]

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.1,
    decay_steps=10000,
    decay_rate=0.95)

adagrad = tf.keras.optimizers.Adagrad(learning_rate=lr_schedule)
adadelta = tf.keras.optimizers.Adadelta(learning_rate=lr_schedule)

# to use customized loss, choose from  discounted_l1 or max_displacement_error function as loss parameter 
final_model.compile(loss=v3_displacement_error, optimizer=adadelta, metrics=mtrc)
final_model.load_weights('/home/lab1/repo/planning/traj_pred/veh_models/veh_139.h5')

history=final_model.fit(X_train, 
                        y_train, epochs=n_epoch, 
                        batch_size=n_batch, 
                        verbose=2, 
                        validation_data=(X_val, y_val),
                        callbacks=[cp_callback])
# Out:
# Train on 300000 samples, validate on 60000 samples
# Epoch 1/50
#
# Epoch 00001: val_loss improved from inf to 1.08890, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_m.h5
# 300000/300000 - 1225s - loss: 1.1483 - mean_absolute_error: 0.5304 - val_loss: 1.0889 - val_mean_absolute_error: 0.4076
# Epoch 2/50
#
# Epoch 00002: val_loss improved from 1.08890 to 1.02943, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_m.h5
# 300000/300000 - 1225s - loss: 1.1337 - mean_absolute_error: 0.4445 - val_loss: 1.0294 - val_mean_absolute_error: 0.3689
# Epoch 3/50
#
# Epoch 00003: val_loss did not improve from 1.02943
# 300000/300000 - 1225s - loss: 1.1192 - mean_absolute_error: 0.4122 - val_loss: 1.3007 - val_mean_absolute_error: 0.5135
# Epoch 4/50
#
# Epoch 00004: val_loss improved from 1.02943 to 0.99901, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_m.h5
# 300000/300000 - 1225s - loss: 1.0890 - mean_absolute_error: 0.3869 - val_loss: 0.9990 - val_mean_absolute_error: 0.3338
# Epoch 5/50
#
# Epoch 00005: val_loss did not improve from 0.99901
# 300000/300000 - 1225s - loss: 1.0555 - mean_absolute_error: 0.3680 - val_loss: 1.0132 - val_mean_absolute_error: 0.3325
# Epoch 6/50
#
# Epoch 00006: val_loss improved from 0.99901 to 0.96025, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_m.h5
# 300000/300000 - 1224s - loss: 1.0205 - mean_absolute_error: 0.3522 - val_loss: 0.9602 - val_mean_absolute_error: 0.3284
# Epoch 7/50
#
# Epoch 00007: val_loss did not improve from 0.96025
# 300000/300000 - 1225s - loss: 0.9848 - mean_absolute_error: 0.3384 - val_loss: 0.9639 - val_mean_absolute_error: 0.3185
# Epoch 8/50
#
# Epoch 00008: val_loss improved from 0.96025 to 0.85508, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_m.h5
# 300000/300000 - 1226s - loss: 0.9513 - mean_absolute_error: 0.3266 - val_loss: 0.8551 - val_mean_absolute_error: 0.2724
# Epoch 9/50
#
# Epoch 00009: val_loss did not improve from 0.85508
# 300000/300000 - 1223s - loss: 0.9171 - mean_absolute_error: 0.3151 - val_loss: 0.9611 - val_mean_absolute_error: 0.3395
# Epoch 10/50
#
# Epoch 00010: val_loss did not improve from 0.85508
# 300000/300000 - 1225s - loss: 0.8846 - mean_absolute_error: 0.3046 - val_loss: 0.8645 - val_mean_absolute_error: 0.3061
# Epoch 11/50
#
# Epoch 00011: val_loss did not improve from 0.85508
# 300000/300000 - 1225s - loss: 0.8544 - mean_absolute_error: 0.2954 - val_loss: 0.9001 - val_mean_absolute_error: 0.3151
# Epoch 12/50
#
# Epoch 00012: val_loss did not improve from 0.85508
# 300000/300000 - 1224s - loss: 0.8262 - mean_absolute_error: 0.2874 - val_loss: 0.9979 - val_mean_absolute_error: 0.4193
# Epoch 13/50
#
# Epoch 00013: val_loss improved from 0.85508 to 0.76081, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_m.h5
# 300000/300000 - 1224s - loss: 0.7991 - mean_absolute_error: 0.2798 - val_loss: 0.7608 - val_mean_absolute_error: 0.2521
# Epoch 14/50
#
# Epoch 00014: val_loss did not improve from 0.76081
# 300000/300000 - 1224s - loss: 0.7742 - mean_absolute_error: 0.2733 - val_loss: 0.8054 - val_mean_absolute_error: 0.3096
# Epoch 15/50
#
# Epoch 00015: val_loss improved from 0.76081 to 0.67860, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_m.h5
# 300000/300000 - 1223s - loss: 0.7489 - mean_absolute_error: 0.2661 - val_loss: 0.6786 - val_mean_absolute_error: 0.2149
# Epoch 16/50
#
# Epoch 00016: val_loss did not improve from 0.67860
# 300000/300000 - 1224s - loss: 0.7267 - mean_absolute_error: 0.2606 - val_loss: 0.6898 - val_mean_absolute_error: 0.2500
# Epoch 17/50
#
# Epoch 00017: val_loss improved from 0.67860 to 0.66583, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_m.h5
# 300000/300000 - 1223s - loss: 0.7052 - mean_absolute_error: 0.2551 - val_loss: 0.6658 - val_mean_absolute_error: 0.2229
# Epoch 18/50
#
# Epoch 00018: val_loss did not improve from 0.66583
# 300000/300000 - 1221s - loss: 0.6850 - mean_absolute_error: 0.2500 - val_loss: 0.6789 - val_mean_absolute_error: 0.2555
# Epoch 19/50
#
# Epoch 00019: val_loss did not improve from 0.66583
# 300000/300000 - 1222s - loss: 0.6653 - mean_absolute_error: 0.2451 - val_loss: 0.6914 - val_mean_absolute_error: 0.2613
# Epoch 20/50
#
# Epoch 00020: val_loss improved from 0.66583 to 0.62022, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_m.h5
# 300000/300000 - 1224s - loss: 0.6474 - mean_absolute_error: 0.2408 - val_loss: 0.6202 - val_mean_absolute_error: 0.2342
# Epoch 21/50
#
# Epoch 00021: val_loss improved from 0.62022 to 0.60079, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_m.h5
# 300000/300000 - 1223s - loss: 0.6298 - mean_absolute_error: 0.2364 - val_loss: 0.6008 - val_mean_absolute_error: 0.2139
# Epoch 22/50
#
# Epoch 00022: val_loss did not improve from 0.60079
# 300000/300000 - 1224s - loss: 0.6143 - mean_absolute_error: 0.2331 - val_loss: 0.6042 - val_mean_absolute_error: 0.2379
# Epoch 23/50
#
# Epoch 00023: val_loss improved from 0.60079 to 0.57447, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_m.h5
# 300000/300000 - 1223s - loss: 0.5978 - mean_absolute_error: 0.2287 - val_loss: 0.5745 - val_mean_absolute_error: 0.2081
# Epoch 24/50
#
# Epoch 00024: val_loss improved from 0.57447 to 0.53584, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_m.h5
# 300000/300000 - 1223s - loss: 0.5839 - mean_absolute_error: 0.2260 - val_loss: 0.5358 - val_mean_absolute_error: 0.2041
# Epoch 25/50
#
# Epoch 00025: val_loss did not improve from 0.53584
# 300000/300000 - 1223s - loss: 0.5701 - mean_absolute_error: 0.2229 - val_loss: 0.5378 - val_mean_absolute_error: 0.1991
# Epoch 26/50
#
# Epoch 00026: val_loss did not improve from 0.53584
# 300000/300000 - 1223s - loss: 0.5569 - mean_absolute_error: 0.2199 - val_loss: 0.5703 - val_mean_absolute_error: 0.2406
# Epoch 27/50
#
# Epoch 00027: val_loss did not improve from 0.53584
# 300000/300000 - 1221s - loss: 0.5444 - mean_absolute_error: 0.2173 - val_loss: 0.5969 - val_mean_absolute_error: 0.2493
# Epoch 28/50
#
# Epoch 00028: val_loss improved from 0.53584 to 0.50538, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_m.h5
# 300000/300000 - 1222s - loss: 0.5332 - mean_absolute_error: 0.2151 - val_loss: 0.5054 - val_mean_absolute_error: 0.2061
# Epoch 29/50
#
# Epoch 00029: val_loss did not improve from 0.50538
# 300000/300000 - 1223s - loss: 0.5215 - mean_absolute_error: 0.2124 - val_loss: 0.5360 - val_mean_absolute_error: 0.2195
# Epoch 30/50
#
# Epoch 00030: val_loss improved from 0.50538 to 0.48361, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_m.h5
# 300000/300000 - 1222s - loss: 0.5111 - mean_absolute_error: 0.2104 - val_loss: 0.4836 - val_mean_absolute_error: 0.1998
# Epoch 31/50
#
# Epoch 00031: val_loss did not improve from 0.48361
# 300000/300000 - 1222s - loss: 0.5007 - mean_absolute_error: 0.2081 - val_loss: 0.5438 - val_mean_absolute_error: 0.2358
# Epoch 32/50
#
# Epoch 00032: val_loss improved from 0.48361 to 0.46637, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_m.h5
# 300000/300000 - 1222s - loss: 0.4910 - mean_absolute_error: 0.2062 - val_loss: 0.4664 - val_mean_absolute_error: 0.1983
# Epoch 33/50
#
# Epoch 00033: val_loss did not improve from 0.46637
# 300000/300000 - 1222s - loss: 0.4823 - mean_absolute_error: 0.2045 - val_loss: 0.4686 - val_mean_absolute_error: 0.1925
# Epoch 34/50
#
# Epoch 00034: val_loss improved from 0.46637 to 0.46511, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_m.h5
# 300000/300000 - 1222s - loss: 0.4738 - mean_absolute_error: 0.2029 - val_loss: 0.4651 - val_mean_absolute_error: 0.2031
# Epoch 35/50
#
# Epoch 00035: val_loss improved from 0.46511 to 0.45706, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_m.h5
# 300000/300000 - 1222s - loss: 0.4654 - mean_absolute_error: 0.2012 - val_loss: 0.4571 - val_mean_absolute_error: 0.1934
# Epoch 36/50
#
# Epoch 00036: val_loss improved from 0.45706 to 0.44550, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_m.h5
# 300000/300000 - 1224s - loss: 0.4577 - mean_absolute_error: 0.1997 - val_loss: 0.4455 - val_mean_absolute_error: 0.1963
# Epoch 37/50
#
# Epoch 00037: val_loss did not improve from 0.44550
# 300000/300000 - 1222s - loss: 0.4505 - mean_absolute_error: 0.1984 - val_loss: 0.4529 - val_mean_absolute_error: 0.1982
# Epoch 38/50
#
# Epoch 00038: val_loss improved from 0.44550 to 0.42279, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_m.h5
# 300000/300000 - 1222s - loss: 0.4436 - mean_absolute_error: 0.1972 - val_loss: 0.4228 - val_mean_absolute_error: 0.1897
# Epoch 39/50
#
# Epoch 00039: val_loss did not improve from 0.42279
# 300000/300000 - 1222s - loss: 0.4365 - mean_absolute_error: 0.1956 - val_loss: 0.4389 - val_mean_absolute_error: 0.1941
# Epoch 40/50
#
# Epoch 00040: val_loss did not improve from 0.42279
# 300000/300000 - 1223s - loss: 0.4304 - mean_absolute_error: 0.1947 - val_loss: 0.4232 - val_mean_absolute_error: 0.1951
# Epoch 41/50
#
# Epoch 00041: val_loss did not improve from 0.42279
# 300000/300000 - 1222s - loss: 0.4243 - mean_absolute_error: 0.1936 - val_loss: 0.4319 - val_mean_absolute_error: 0.1957
# Epoch 42/50
#
# Epoch 00042: val_loss improved from 0.42279 to 0.41279, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_m.h5
# 300000/300000 - 1223s - loss: 0.4185 - mean_absolute_error: 0.1924 - val_loss: 0.4128 - val_mean_absolute_error: 0.1951
# Epoch 43/50
#
# Epoch 00043: val_loss did not improve from 0.41279
# 300000/300000 - 1220s - loss: 0.4132 - mean_absolute_error: 0.1916 - val_loss: 0.4228 - val_mean_absolute_error: 0.1951
# Epoch 44/50
#
# Epoch 00044: val_loss improved from 0.41279 to 0.39694, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_m.h5
# 300000/300000 - 1223s - loss: 0.4081 - mean_absolute_error: 0.1907 - val_loss: 0.3969 - val_mean_absolute_error: 0.1876
# Epoch 45/50
#
# Epoch 00045: val_loss did not improve from 0.39694
# 300000/300000 - 1222s - loss: 0.4029 - mean_absolute_error: 0.1896 - val_loss: 0.4082 - val_mean_absolute_error: 0.1908
# Epoch 46/50
#
# Epoch 00046: val_loss improved from 0.39694 to 0.39050, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_m.h5
# 300000/300000 - 1221s - loss: 0.3986 - mean_absolute_error: 0.1891 - val_loss: 0.3905 - val_mean_absolute_error: 0.1885
# Epoch 47/50
#
# Epoch 00047: val_loss did not improve from 0.39050
# 300000/300000 - 1222s - loss: 0.3940 - mean_absolute_error: 0.1882 - val_loss: 0.4007 - val_mean_absolute_error: 0.1904
# Epoch 48/50
#
# Epoch 00048: val_loss improved from 0.39050 to 0.38293, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_m.h5
# 300000/300000 - 1221s - loss: 0.3897 - mean_absolute_error: 0.1874 - val_loss: 0.3829 - val_mean_absolute_error: 0.1874
# Epoch 49/50
#
# Epoch 00049: val_loss did not improve from 0.38293
# 300000/300000 - 1221s - loss: 0.3858 - mean_absolute_error: 0.1868 - val_loss: 0.3876 - val_mean_absolute_error: 0.1863
# Epoch 50/50
#
# Epoch 00050: val_loss improved from 0.38293 to 0.37189, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_m.h5
# 300000/300000 - 1223s - loss: 0.3820 - mean_absolute_error: 0.1862 - val_loss: 0.3719 - val_mean_absolute_error: 0.1833

# %%
print("Evaluate on test data")
results = final_model.evaluate(X_test, y_test, batch_size=32)
print("test loss, test acc:", results)


_history_path = home+ '/repo/planning/traj_pred/total_model_history/veh_history.sav'
pickle.dump(history.history, open(_history_path, 'wb'))

_weights_path =  home+ '/repo/planning/traj_pred/total_model_history/veh_weights.h5'
final_model.save_weights(_weights_path)
# Out:
# Evaluate on test data
# test loss, test acc: [0.37023132952054344, 0.18216228]

# %%
################################DONE

# %%
# In[ ]:
# X_val, X_test, y_val, y_test,X_train, , y_train,

# %%
history.history.keys()
ax1,=plt.plot( history.history['loss'], c='b', label='Training loss')
ax2,=plt.plot( history.history['val_loss'], c='r', label='Validation loss')

plt.legend(handles=[ax1])
plt.title('loss')
plt.show()

# %%
# final_model.compile(loss=v3_displacement_error, optimizer=adadelta, metrics=mtrc)
# final_model.load_weights('home+ '/repo/planning/traj_pred/total_model_history/veh_weights.h5'')

# %%
# ##prediction
# # from utilities import get_position_sequence
# def get_position_sequence(prev, new):
#     arr = np.delete(prev, 0, 0)
#     a=np.vstack((arr,new))
#     return a 

# def get_sequence_prediction(X_position_test, i):
#     results =[]
#     s=X_position_test[i]
#     for count in range(0,50):
        
#         result = final_model.predict(np.array([s]))
# #         print(result)
#         results.append(result[0])
#         s = get_position_sequence(s, result)
#     results=np.array(results)
# #     print(s.shape,results.shape)
    
#     return results

# # i= np.random.randint(0, len(X_test))
# # results = get_sequence_prediction(X_test, i)
# # print(results.shape)

# test=np.load('vehicle_test_history.npy')
# v_predict=[]
# print(len(test))
# for i in range(len(test)):
#     print(i)
#     results = get_sequence_prediction(test, i)
#     v_predict.append(results)
# np.save("v_predictions",v_predict)

# print('done')

# %%
# print(np.array(v_predict).shape)
# np.save("v_predictions",v_predict)
# print('done')

# %%
# i= np.random.randint(0, len(X_test))


# # In[ ]:
# # i =2273

# # i=1574
# # i=3070

# # i=387,39
# # i=667
# # i=15
# print("showing trip", i)


# # from utilities import get_position_sequence
# def get_position_sequence(prev, new):
#     arr = np.delete(prev, 0, 0)
#     a=np.vstack((arr,new))
#     return a 

# def get_sequence_prediction(X_position_test, i):
#     results =[]
#     s=X_position_test[i]
#     for count in range(0,12):
        
#         result = final_model.predict(np.array([s]))
# #         print(result)
#         results.append(result[0])
#         s = get_position_sequence(s, result)
#     results=np.array(results)
# #     print(s.shape,results.shape)
    
#     return results

# results = get_sequence_prediction(X_test, i)

# # print(len(results))
# # print("sss",results)

# ax1 =plt.scatter(y_test[i][:,0],y_test[i][:,1],color='b',label='Ground truth')

# ax2 =plt.scatter(X_test[i][:,0],X_test[i][:,1],color='r', label='Training segment')


# ax3 =plt.scatter(results[:,0],results[:,1],color='g', label='Prediction')
# # ax3 =plt.scatter(result[0][0],result[0][1],color='g', label='Prediction')

# plt.legend(handles=[ax1, ax2, ax3])
# plt.show()

# distance = v3_displacement_error(results,y_test[i] )
# avg = K.mean(distance)
# pl =[]
# # tf.print(distance,output_stream=sys.stderr)
# with tf.compat.v1.Session() as sess: pl=distance.eval(), print(distance.eval(),'\naverage',avg.eval()) 
# import matplotlib.pyplot as plt
# # print(pl[0])
# plt.plot(pl[0])
# plt.title('Displacement error')
# plt.show()

# %%
# final_displacement=[]
# avg_displacement=[]

# # for idx in range(0,len(X_test)):
# for idx in range(0,1000):
#     p=[]
#     re= get_sequence_prediction(X_test, idx)
#     distance = v3_displacement_error(re,y_test[idx] )
#     avg = K.mean(distance)
    
#     with tf.compat.v1.Session() as sess:
#         p=distance.eval()
#         ax =avg.eval()
# #     print(p,ax)
#     final_displacement.append(p)
#     avg_displacement.append(ax)

# final_displacement = np.array(final_displacement)
# sec=[]

# for j in range(0,final_displacement.shape[1]):
#     displacement = sum(final_displacement[:,j])/len(final_displacement)
    
#     sec.append(displacement)
# print("Final displacement error:",sec[-1])
# print("Average displacement error:",sum(avg_displacement)/len(avg_displacement))

# print(sec)
# plt.plot(sec)
# plt.title("average displacement error at each timestep")
# plt.show()

# %%
# history2 = pickle.load(open( cwd+ '/saved_model/lab1_txt_max_history_mae_adadelta_600.sav',  "rb") ) 
# history3 = pickle.load(open( cwd+ '/saved_model/lab1_txt_max_history_mae_adadelta.sav',  "rb") )
# print(len(history.history['loss']))
# # plt.plot(range(600,1100),history.history['loss'], c='b')
# # plt.plot( range(300,600), history2['loss'], c='b')
# plt.plot( history3['loss'], c='b')
# plt.title('train loss')

# # plt.plot(range(600,1100),history.history['val_loss'], c='r')
# # plt.plot( range(300,600), history2['val_loss'], c='r')
# plt.plot( history3['val_loss'], c='r')
# plt.title('loss')


# plt.show()
