# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:



import numpy as np 
import pandas as pd 
import warnings 
warnings.filterwarnings("ignore")
import tensorflow as tf 


print(tf.__version__)

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Bidirectional
from tensorflow.keras.layers import GRU
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import TimeDistributed
from tensorflow.keras.layers import RepeatVector
from tensorflow.keras import Input
from tensorflow.keras.layers import Flatten, Reshape
from tensorflow.keras import Model
from tensorflow.keras.layers import Conv2D,concatenate
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Dropout
from attention import Attention_Block
# from attention import attention_block
from tensorflow.keras.layers import Attention
from step_attention import AttentionAugmentation2D, _normalize_depth_vars
# from keras.models import load_model

# In[2]:


# from google.colab import drive
# drive.mount('/content/drive')



# In[3]:


from loss import discounted_l1, max_displacement_error,v3_displacement_error
import math
import pickle5 as pickle
import matplotlib.pyplot as plt
from numpy import array
# import horovod.tensorflow.keras as hvd
# Out:
# 2.2.0

# %%
# hvd.init()

# In[4]:

import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]="2"


gpus = tf.config.experimental.list_logical_devices('GPU')
print(gpus)


if gpus:
    
    try:
        
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu,True)
    except:
        print('checking gpu error')
print('checking GPUs')


from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
config=tf.compat.v1.ConfigProto()
# config.gpu_options.visible_device_list= '0,1'
config.gpu_options.allow_growth=True

config.log_device_placement=True
# config.visible_device_list =2
sess=tf.compat.v1.Session(config=config)

tf.compat.v1.keras.backend.set_session(sess)


# In[5]:


from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras import initializers
import tensorflow.keras.backend as K
from sklearn.model_selection import train_test_split

from load_data import load_data
import os
# Out:
# [LogicalDevice(name='/device:GPU:0', device_type='GPU')]
# checking gpu error
# checking GPUs
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: TITAN X (Pascal), pci bus id: 0000:09:00.0, compute capability: 6.1

# %%
# train_X_route = '/home/lab1/repo/lyft/newarray/training_features_vehicle.npy'
# # test_route = home+'/repo/data/X_to_val.npy'

# train_y_route = '/home/lab1/repo/lyft/newarray/training_labels_vehicle.npy'
# test_y_route = home+'/repo/data/y_to_val.npy'
prefix ='/home/lab1/repo/planning/traj_pred/data/'
train_raw, test_raw=None, None
for i in range(1):
    name_tr= prefix+'veh_train_set_8KfB'+'.npy'
    name_te= prefix+'veh_test_set_8KfB'+'.npy'
    tr = np.load(name_tr,allow_pickle=True).astype(float)
    te = np.load(name_te,allow_pickle=True).astype(float)
    if train_raw is None:
        train_raw=tr
    else:
        train_raw= np.vstack((train_raw, tr))
    
    if test_raw is None:
        test_raw=te
    else:
        test_raw= np.vstack((test_raw, te))

print(train_raw.shape, test_raw.shape)
# Out:
# (94440, 11, 4) (2362, 20, 4)

# %%
np.random.shuffle(train_raw)
np.random.shuffle(test_raw)
max_n=len(train_raw)
# test_maxn=int(max_n*0.2)
train_set = train_raw[:max_n]
X_train=train_set[:,:10,2:4]
y_train=train_set[:,10,2:4]

# test_set = test_raw[:test_maxn]
test_set = test_raw
X_test=test_set[:,:10,2:4]
y_test=test_set[:,10,2:4]
y = test_set[:,10:,2:4]

print(X_train.shape, y_train.shape, X_test.shape, y_test.shape, y.shape)
# Out:
# (94440, 10, 2) (94440, 2) (2362, 10, 2) (2362, 2) (2362, 10, 2)

# %%
# print(X_position.shape, y.shape, X.shape)
print(X_train.shape, y_train.shape)
print(y_train[0])
# Out:
# (94440, 10, 2) (94440, 2)
# [-32.81964111 -50.24951172]

# %%
from sklearn.utils import shuffle

n_test=int(len(X_train)*0.9)
X_train, X_val, y_train, y_val= \
X_train[:n_test], X_train[n_test:], y_train[:n_test], y_train[n_test:]
# y=test_set[:n_test,10:,2:4]


print(X_val.shape, y_val.shape)
# Out:
# (9444, 10, 2) (9444, 2)

# %%
np.save("train_data/v_xval_8kfb",X_val)
np.save('train_data/v_yval_8kfb',y_val)
np.save("train_data/v_xtrain_8kfb",X_train)
np.save("train_data/v_ytrain_8kfb",y_train)
np.save("train_data/v_xtest_8kfb",X_test)
np.save("train_data/v_ytest_8kfb",y_test)
np.save("train_data/v_y_8kfb",y) # y is the full gt trajectory of xtest, relative coordinate
np.save('train_data/v_test_xall_8kfb',test_set ) # test set, including xtest and y as well as global coordinate

# %%
X_val = np.load("train_data/v_xval_8kfb.npy")
y_val = np.load('train_data/v_yval_8kfb.npy')
X_train = np.load("train_data/v_xtrain_8kfb.npy")
y_train = np.load("train_data/v_ytrain_8kfb.npy")
X_test = np.load("train_data/v_xtest_8kfb.npy")
y_test = np.load("train_data/v_ytest_8kfb.npy")
y = np.load("train_data/v_y_8kfb.npy") # y is the full gt trajectory of xtest, relative coordinate
test_set = np.load('train_data/v_test_xall_8kfb.npy' ) #
from pathlib import Path
home = str(Path.home())

# %%
print(X_val.shape, X_train.shape, y.shape, X_test.shape)
# Out:
# (9444, 10, 2) (84996, 10, 2) (2362, 10, 2) (2362, 10, 2)

# %%
# In[9]:


filters=20
kernel_size = (3,3)
strides = (1,1)
depth_k =0.2
depth_v =0.2

channel_axis = 1 if K.image_data_format() == 'channels_first' else -1
print("before normalized k, v",depth_k,depth_k,strides)
depth_k, depth_v = _normalize_depth_vars(depth_k, depth_v, filters)
print("after normalized k, v",depth_k,depth_k,strides)


# In[10]:
time_step=10
tf.compat.v1.disable_eager_execution()

rnn = Sequential()
rnn.add(LSTM(128, return_sequences=True, kernel_regularizer='l1', input_shape=(time_step,2)))
rnn.add(LSTM(256, return_sequences=True, kernel_regularizer='l1',input_shape=(time_step,128)))
rnn.add(Reshape((time_step,16,16,1)))
rnn.summary()



cnn = Sequential()

cnn.add(Conv2D(1024, (4, 4),input_shape=(16, 16, 1)))
cnn.add(Conv2D(512, (2, 2)))
cnn.add(Conv2D(256, (4, 4)))
cnn.add(Conv2D(128, (2, 2)))
cnn.add(MaxPooling2D(2,2))
cnn.add(Conv2D(64, (2, 2)))
cnn.add(Conv2D(32, (2, 2)))
cnn.add(Conv2D(16, (2, 2)))

#attention block below
cnn.add(Conv2D(2 * depth_k + depth_k, (1, 1), strides))
cnn.add(AttentionAugmentation2D(depth_k, depth_v, num_heads=4, relative=True))

# cnn.add(Dropout(0.5))
cnn.add(Flatten())

 
cnn.add(Dense(128))
cnn.add(Dense(32))

cnn.summary() 



rnn2=Sequential()
rnn2.add(GRU(256, input_shape=(time_step,32)))


dense = Sequential()
dense.add(Dense(128))
dense.add(Dense(64))
dense.add(Dense(2)) # Model output

main_input = Input(shape=(time_step,2)) 
model = rnn(main_input)
model = TimeDistributed(cnn)(model) 
 # combine timedistributed cnn, attention, and fully connected network with rnn
model = rnn2(model)
model = dense(model) # add dense
final_model = Model(inputs=main_input, outputs=model)
final_model.summary()
# Out:
# before normalized k, v 0.2 0.2 (1, 1)
# after normalized k, v 4 4 (1, 1)
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:From /home/lab1/miniconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 10, 128)           67072
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 10, 256)           394240
# _________________________________________________________________
# reshape (Reshape)            (None, 10, 16, 16, 1)     0
# =================================================================
# Total params: 461,312
# Trainable params: 461,312
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 13, 13, 1024)      17408
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 12, 12, 512)       2097664
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 9, 256)         2097408
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 128)         131200
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 3, 3, 64)          32832
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 2, 2, 32)          8224
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 1, 1, 16)          2064
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 1, 1, 12)          204
# _________________________________________________________________
# attention_augmentation2d (At (None, 1, 1, 4)           2
# _________________________________________________________________
# flatten (Flatten)            (None, 4)                 0
# _________________________________________________________________
# dense (Dense)                (None, 128)               640
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                4128
# =================================================================
# Total params: 4,391,774
# Trainable params: 4,391,774
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Layer gru will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 10, 2)]           0
# _________________________________________________________________
# sequential (Sequential)      (None, 10, 16, 16, 1)     461312
# _________________________________________________________________
# time_distributed (TimeDistri (None, 10, 32)            4391774
# _________________________________________________________________
# sequential_2 (Sequential)    (None, 256)               222720
# _________________________________________________________________
# sequential_3 (Sequential)    (None, 2)                 41282
# =================================================================
# Total params: 5,117,088
# Trainable params: 5,117,088
# Non-trainable params: 0
# _________________________________________________________________

# %%
# print(home)

# %%
n_batch = 32
n_epoch  = 200


checkpoint_path =home+ "/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5"
checkpoint_dir = os.path.dirname(checkpoint_path)


# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_best_only=True,
                                                 save_weights_only=True,
                                                 verbose=1)


 #(None, n_steps, n_features)

sgd = tf.keras.optimizers.SGD(learning_rate=0.1, momentum=0.5, nesterov=True)
rmsprop =tf.keras.optimizers.RMSprop(learning_rate=0.001)



ftrl = tf.keras.optimizers.Ftrl(learning_rate=0.01)


mtrc = [tf.keras.metrics.MeanAbsoluteError()]
# [tf.keras.metrics.CosineSimilarity(axis=1)]

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.1,
    decay_steps=10000,
    decay_rate=0.95)

adagrad = tf.keras.optimizers.Adagrad(learning_rate=lr_schedule)
adadelta = tf.keras.optimizers.Adadelta(learning_rate=lr_schedule)

# to use customized loss, choose from  discounted_l1 or max_displacement_error function as loss parameter 
final_model.compile(loss=v3_displacement_error, optimizer=adadelta, metrics=mtrc)
# final_model.load_weights('/home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb.h5')

history=final_model.fit(X_train, 
                        y_train, epochs=n_epoch, 
                        batch_size=n_batch, 
                        verbose=2, 
                        validation_data=(X_val, y_val),
                        callbacks=[cp_callback])
# Out:
# Train on 84996 samples, validate on 9444 samples
# Epoch 1/200
#
# Epoch 00001: val_loss improved from inf to 3.89757, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 339s - loss: 8.9835 - mean_absolute_error: 2.6579 - val_loss: 3.8976 - val_mean_absolute_error: 1.6247
# Epoch 2/200
#
# Epoch 00002: val_loss improved from 3.89757 to 3.47874, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 338s - loss: 2.7407 - mean_absolute_error: 0.9917 - val_loss: 3.4787 - val_mean_absolute_error: 1.5963
# Epoch 3/200
#
# Epoch 00003: val_loss improved from 3.47874 to 2.01976, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 341s - loss: 2.2831 - mean_absolute_error: 0.8336 - val_loss: 2.0198 - val_mean_absolute_error: 0.6822
# Epoch 4/200
#
# Epoch 00004: val_loss improved from 2.01976 to 1.97540, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 361s - loss: 2.0610 - mean_absolute_error: 0.7618 - val_loss: 1.9754 - val_mean_absolute_error: 0.7172
# Epoch 5/200
#
# Epoch 00005: val_loss did not improve from 1.97540
# 84996/84996 - 370s - loss: 1.9170 - mean_absolute_error: 0.7117 - val_loss: 2.0484 - val_mean_absolute_error: 0.8392
# Epoch 6/200
#
# Epoch 00006: val_loss did not improve from 1.97540
# 84996/84996 - 372s - loss: 1.8190 - mean_absolute_error: 0.6762 - val_loss: 2.3931 - val_mean_absolute_error: 1.0063
# Epoch 7/200
#
# Epoch 00007: val_loss improved from 1.97540 to 1.76804, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 372s - loss: 1.7235 - mean_absolute_error: 0.6345 - val_loss: 1.7680 - val_mean_absolute_error: 0.6629
# Epoch 8/200
#
# Epoch 00008: val_loss did not improve from 1.76804
# 84996/84996 - 375s - loss: 1.6583 - mean_absolute_error: 0.6091 - val_loss: 2.0449 - val_mean_absolute_error: 0.8207
# Epoch 9/200
#
# Epoch 00009: val_loss did not improve from 1.76804
# 84996/84996 - 376s - loss: 1.6012 - mean_absolute_error: 0.5857 - val_loss: 2.2101 - val_mean_absolute_error: 0.9733
# Epoch 10/200
#
# Epoch 00010: val_loss did not improve from 1.76804
# 84996/84996 - 375s - loss: 1.5405 - mean_absolute_error: 0.5585 - val_loss: 2.1637 - val_mean_absolute_error: 0.9991
# Epoch 11/200
#
# Epoch 00011: val_loss improved from 1.76804 to 1.68954, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 374s - loss: 1.4938 - mean_absolute_error: 0.5375 - val_loss: 1.6895 - val_mean_absolute_error: 0.6497
# Epoch 12/200
#
# Epoch 00012: val_loss did not improve from 1.68954
# 84996/84996 - 374s - loss: 1.4539 - mean_absolute_error: 0.5211 - val_loss: 1.8414 - val_mean_absolute_error: 0.7809
# Epoch 13/200
#
# Epoch 00013: val_loss did not improve from 1.68954
# 84996/84996 - 375s - loss: 1.4134 - mean_absolute_error: 0.5030 - val_loss: 1.6900 - val_mean_absolute_error: 0.6760
# Epoch 14/200
#
# Epoch 00014: val_loss improved from 1.68954 to 1.66719, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 377s - loss: 1.3801 - mean_absolute_error: 0.4882 - val_loss: 1.6672 - val_mean_absolute_error: 0.6805
# Epoch 15/200
#
# Epoch 00015: val_loss improved from 1.66719 to 1.54445, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 375s - loss: 1.3558 - mean_absolute_error: 0.4796 - val_loss: 1.5444 - val_mean_absolute_error: 0.5940
# Epoch 16/200
#
# Epoch 00016: val_loss improved from 1.54445 to 1.42203, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 376s - loss: 1.3188 - mean_absolute_error: 0.4620 - val_loss: 1.4220 - val_mean_absolute_error: 0.5207
# Epoch 17/200
#
# Epoch 00017: val_loss did not improve from 1.42203
# 84996/84996 - 375s - loss: 1.2960 - mean_absolute_error: 0.4534 - val_loss: 1.7174 - val_mean_absolute_error: 0.7025
# Epoch 18/200
#
# Epoch 00018: val_loss did not improve from 1.42203
# 84996/84996 - 375s - loss: 1.2737 - mean_absolute_error: 0.4444 - val_loss: 1.5893 - val_mean_absolute_error: 0.6253
# Epoch 19/200
#
# Epoch 00019: val_loss did not improve from 1.42203
# 84996/84996 - 376s - loss: 1.2479 - mean_absolute_error: 0.4333 - val_loss: 1.8004 - val_mean_absolute_error: 0.7390
# Epoch 20/200
#
# Epoch 00020: val_loss did not improve from 1.42203
# 84996/84996 - 374s - loss: 1.2275 - mean_absolute_error: 0.4265 - val_loss: 1.7521 - val_mean_absolute_error: 0.7383
# Epoch 21/200
#
# Epoch 00021: val_loss improved from 1.42203 to 1.18725, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 375s - loss: 1.2020 - mean_absolute_error: 0.4152 - val_loss: 1.1872 - val_mean_absolute_error: 0.4097
# Epoch 22/200
#
# Epoch 00022: val_loss did not improve from 1.18725
# 84996/84996 - 373s - loss: 1.1838 - mean_absolute_error: 0.4090 - val_loss: 1.5504 - val_mean_absolute_error: 0.6088
# Epoch 23/200
#
# Epoch 00023: val_loss did not improve from 1.18725
# 84996/84996 - 375s - loss: 1.1618 - mean_absolute_error: 0.4006 - val_loss: 1.3067 - val_mean_absolute_error: 0.4875
# Epoch 24/200
#
# Epoch 00024: val_loss did not improve from 1.18725
# 84996/84996 - 376s - loss: 1.1408 - mean_absolute_error: 0.3926 - val_loss: 1.4362 - val_mean_absolute_error: 0.5788
# Epoch 25/200
#
# Epoch 00025: val_loss did not improve from 1.18725
# 84996/84996 - 374s - loss: 1.1244 - mean_absolute_error: 0.3871 - val_loss: 1.5123 - val_mean_absolute_error: 0.5863
# Epoch 26/200
#
# Epoch 00026: val_loss did not improve from 1.18725
# 84996/84996 - 373s - loss: 1.1096 - mean_absolute_error: 0.3825 - val_loss: 1.3631 - val_mean_absolute_error: 0.5119
# Epoch 27/200
#
# Epoch 00027: val_loss did not improve from 1.18725
# 84996/84996 - 377s - loss: 1.0916 - mean_absolute_error: 0.3763 - val_loss: 1.2208 - val_mean_absolute_error: 0.4509
# Epoch 28/200
#
# Epoch 00028: val_loss did not improve from 1.18725
# 84996/84996 - 377s - loss: 1.0744 - mean_absolute_error: 0.3705 - val_loss: 1.4408 - val_mean_absolute_error: 0.6275
# Epoch 29/200
#
# Epoch 00029: val_loss did not improve from 1.18725
# 84996/84996 - 377s - loss: 1.0581 - mean_absolute_error: 0.3644 - val_loss: 1.2609 - val_mean_absolute_error: 0.4904
# Epoch 30/200
#
# Epoch 00030: val_loss did not improve from 1.18725
# 84996/84996 - 379s - loss: 1.0444 - mean_absolute_error: 0.3603 - val_loss: 1.4801 - val_mean_absolute_error: 0.6556
# Epoch 31/200
#
# Epoch 00031: val_loss did not improve from 1.18725
# 84996/84996 - 380s - loss: 1.0301 - mean_absolute_error: 0.3553 - val_loss: 1.2394 - val_mean_absolute_error: 0.4827
# Epoch 32/200
#
# Epoch 00032: val_loss did not improve from 1.18725
# 84996/84996 - 377s - loss: 1.0154 - mean_absolute_error: 0.3503 - val_loss: 1.5763 - val_mean_absolute_error: 0.6871
# Epoch 33/200
#
# Epoch 00033: val_loss did not improve from 1.18725
# 84996/84996 - 375s - loss: 1.0053 - mean_absolute_error: 0.3477 - val_loss: 1.2087 - val_mean_absolute_error: 0.4597
# Epoch 34/200
#
# Epoch 00034: val_loss did not improve from 1.18725
# 84996/84996 - 376s - loss: 0.9900 - mean_absolute_error: 0.3419 - val_loss: 1.2239 - val_mean_absolute_error: 0.4910
# Epoch 35/200
#
# Epoch 00035: val_loss did not improve from 1.18725
# 84996/84996 - 376s - loss: 0.9790 - mean_absolute_error: 0.3390 - val_loss: 1.4424 - val_mean_absolute_error: 0.6404
# Epoch 36/200
#
# Epoch 00036: val_loss did not improve from 1.18725
# 84996/84996 - 377s - loss: 0.9700 - mean_absolute_error: 0.3369 - val_loss: 1.4514 - val_mean_absolute_error: 0.6058
# Epoch 37/200
#
# Epoch 00037: val_loss did not improve from 1.18725
# 84996/84996 - 377s - loss: 0.9564 - mean_absolute_error: 0.3322 - val_loss: 1.2255 - val_mean_absolute_error: 0.4968
# Epoch 38/200
#
# Epoch 00038: val_loss did not improve from 1.18725
# 84996/84996 - 377s - loss: 0.9448 - mean_absolute_error: 0.3282 - val_loss: 1.4075 - val_mean_absolute_error: 0.5955
# Epoch 39/200
#
# Epoch 00039: val_loss did not improve from 1.18725
# 84996/84996 - 379s - loss: 0.9334 - mean_absolute_error: 0.3247 - val_loss: 1.2011 - val_mean_absolute_error: 0.4775
# Epoch 40/200
#
# Epoch 00040: val_loss did not improve from 1.18725
# 84996/84996 - 381s - loss: 0.9220 - mean_absolute_error: 0.3208 - val_loss: 1.2544 - val_mean_absolute_error: 0.5288
# Epoch 41/200
#
# Epoch 00041: val_loss improved from 1.18725 to 1.09702, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 381s - loss: 0.9112 - mean_absolute_error: 0.3167 - val_loss: 1.0970 - val_mean_absolute_error: 0.4487
# Epoch 42/200
#
# Epoch 00042: val_loss did not improve from 1.09702
# 84996/84996 - 378s - loss: 0.9047 - mean_absolute_error: 0.3162 - val_loss: 1.3470 - val_mean_absolute_error: 0.5982
# Epoch 43/200
#
# Epoch 00043: val_loss did not improve from 1.09702
# 84996/84996 - 380s - loss: 0.8939 - mean_absolute_error: 0.3127 - val_loss: 1.1139 - val_mean_absolute_error: 0.4505
# Epoch 44/200
#
# Epoch 00044: val_loss improved from 1.09702 to 1.09199, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 380s - loss: 0.8850 - mean_absolute_error: 0.3101 - val_loss: 1.0920 - val_mean_absolute_error: 0.4292
# Epoch 45/200
#
# Epoch 00045: val_loss did not improve from 1.09199
# 84996/84996 - 380s - loss: 0.8741 - mean_absolute_error: 0.3066 - val_loss: 1.1413 - val_mean_absolute_error: 0.4896
# Epoch 46/200
#
# Epoch 00046: val_loss did not improve from 1.09199
# 84996/84996 - 378s - loss: 0.8661 - mean_absolute_error: 0.3042 - val_loss: 1.0925 - val_mean_absolute_error: 0.4470
# Epoch 47/200
#
# Epoch 00047: val_loss improved from 1.09199 to 1.07645, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 376s - loss: 0.8594 - mean_absolute_error: 0.3032 - val_loss: 1.0765 - val_mean_absolute_error: 0.4259
# Epoch 48/200
#
# Epoch 00048: val_loss did not improve from 1.07645
# 84996/84996 - 377s - loss: 0.8498 - mean_absolute_error: 0.2999 - val_loss: 1.1763 - val_mean_absolute_error: 0.5078
# Epoch 49/200
#
# Epoch 00049: val_loss did not improve from 1.07645
# 84996/84996 - 377s - loss: 0.8411 - mean_absolute_error: 0.2976 - val_loss: 1.2036 - val_mean_absolute_error: 0.5135
# Epoch 50/200
#
# Epoch 00050: val_loss improved from 1.07645 to 1.01758, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 378s - loss: 0.8315 - mean_absolute_error: 0.2941 - val_loss: 1.0176 - val_mean_absolute_error: 0.3931
# Epoch 51/200
#
# Epoch 00051: val_loss did not improve from 1.01758
# 84996/84996 - 376s - loss: 0.8248 - mean_absolute_error: 0.2930 - val_loss: 1.1137 - val_mean_absolute_error: 0.4708
# Epoch 52/200
#
# Epoch 00052: val_loss did not improve from 1.01758
# 84996/84996 - 380s - loss: 0.8168 - mean_absolute_error: 0.2905 - val_loss: 1.0320 - val_mean_absolute_error: 0.4361
# Epoch 53/200
#
# Epoch 00053: val_loss improved from 1.01758 to 0.91698, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 377s - loss: 0.8087 - mean_absolute_error: 0.2883 - val_loss: 0.9170 - val_mean_absolute_error: 0.3531
# Epoch 54/200
#
# Epoch 00054: val_loss did not improve from 0.91698
# 84996/84996 - 377s - loss: 0.8014 - mean_absolute_error: 0.2859 - val_loss: 1.0381 - val_mean_absolute_error: 0.4397
# Epoch 55/200
#
# Epoch 00055: val_loss did not improve from 0.91698
# 84996/84996 - 377s - loss: 0.7953 - mean_absolute_error: 0.2853 - val_loss: 0.9286 - val_mean_absolute_error: 0.3694
# Epoch 56/200
#
# Epoch 00056: val_loss did not improve from 0.91698
# 84996/84996 - 379s - loss: 0.7858 - mean_absolute_error: 0.2818 - val_loss: 1.1707 - val_mean_absolute_error: 0.5092
# Epoch 57/200
#
# Epoch 00057: val_loss did not improve from 0.91698
# 84996/84996 - 377s - loss: 0.7788 - mean_absolute_error: 0.2798 - val_loss: 0.9273 - val_mean_absolute_error: 0.3704
# Epoch 58/200
#
# Epoch 00058: val_loss improved from 0.91698 to 0.79104, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 379s - loss: 0.7735 - mean_absolute_error: 0.2790 - val_loss: 0.7910 - val_mean_absolute_error: 0.2860
# Epoch 59/200
#
# Epoch 00059: val_loss did not improve from 0.79104
# 84996/84996 - 380s - loss: 0.7657 - mean_absolute_error: 0.2764 - val_loss: 0.8784 - val_mean_absolute_error: 0.3399
# Epoch 60/200
#
# Epoch 00060: val_loss did not improve from 0.79104
# 84996/84996 - 379s - loss: 0.7604 - mean_absolute_error: 0.2753 - val_loss: 0.8826 - val_mean_absolute_error: 0.3511
# Epoch 61/200
#
# Epoch 00061: val_loss did not improve from 0.79104
# 84996/84996 - 378s - loss: 0.7532 - mean_absolute_error: 0.2736 - val_loss: 0.8614 - val_mean_absolute_error: 0.3517
# Epoch 62/200
#
# Epoch 00062: val_loss did not improve from 0.79104
# 84996/84996 - 377s - loss: 0.7470 - mean_absolute_error: 0.2719 - val_loss: 0.9021 - val_mean_absolute_error: 0.3591
# Epoch 63/200
#
# Epoch 00063: val_loss improved from 0.79104 to 0.78776, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 377s - loss: 0.7416 - mean_absolute_error: 0.2712 - val_loss: 0.7878 - val_mean_absolute_error: 0.3044
# Epoch 64/200
#
# Epoch 00064: val_loss did not improve from 0.78776
# 84996/84996 - 377s - loss: 0.7336 - mean_absolute_error: 0.2685 - val_loss: 1.0448 - val_mean_absolute_error: 0.4535
# Epoch 65/200
#
# Epoch 00065: val_loss did not improve from 0.78776
# 84996/84996 - 378s - loss: 0.7278 - mean_absolute_error: 0.2672 - val_loss: 0.8295 - val_mean_absolute_error: 0.3325
# Epoch 66/200
#
# Epoch 00066: val_loss did not improve from 0.78776
# 84996/84996 - 377s - loss: 0.7219 - mean_absolute_error: 0.2655 - val_loss: 0.9387 - val_mean_absolute_error: 0.4132
# Epoch 67/200
#
# Epoch 00067: val_loss did not improve from 0.78776
# 84996/84996 - 379s - loss: 0.7168 - mean_absolute_error: 0.2645 - val_loss: 0.7922 - val_mean_absolute_error: 0.3182
# Epoch 68/200
#
# Epoch 00068: val_loss did not improve from 0.78776
# 84996/84996 - 380s - loss: 0.7106 - mean_absolute_error: 0.2629 - val_loss: 0.8032 - val_mean_absolute_error: 0.3265
# Epoch 69/200
#
# Epoch 00069: val_loss improved from 0.78776 to 0.77544, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 382s - loss: 0.7057 - mean_absolute_error: 0.2623 - val_loss: 0.7754 - val_mean_absolute_error: 0.2972
# Epoch 70/200
#
# Epoch 00070: val_loss did not improve from 0.77544
# 84996/84996 - 382s - loss: 0.7006 - mean_absolute_error: 0.2611 - val_loss: 0.8946 - val_mean_absolute_error: 0.3934
# Epoch 71/200
#
# Epoch 00071: val_loss did not improve from 0.77544
# 84996/84996 - 384s - loss: 0.6928 - mean_absolute_error: 0.2582 - val_loss: 0.8184 - val_mean_absolute_error: 0.3401
# Epoch 72/200
#
# Epoch 00072: val_loss did not improve from 0.77544
# 84996/84996 - 381s - loss: 0.6903 - mean_absolute_error: 0.2588 - val_loss: 0.9096 - val_mean_absolute_error: 0.4149
# Epoch 73/200
#
# Epoch 00073: val_loss improved from 0.77544 to 0.73709, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 382s - loss: 0.6836 - mean_absolute_error: 0.2565 - val_loss: 0.7371 - val_mean_absolute_error: 0.2859
# Epoch 74/200
#
# Epoch 00074: val_loss did not improve from 0.73709
# 84996/84996 - 379s - loss: 0.6789 - mean_absolute_error: 0.2557 - val_loss: 0.7752 - val_mean_absolute_error: 0.3224
# Epoch 75/200
#
# Epoch 00075: val_loss did not improve from 0.73709
# 84996/84996 - 380s - loss: 0.6735 - mean_absolute_error: 0.2545 - val_loss: 0.8045 - val_mean_absolute_error: 0.3351
# Epoch 76/200
#
# Epoch 00076: val_loss did not improve from 0.73709
# 84996/84996 - 383s - loss: 0.6678 - mean_absolute_error: 0.2528 - val_loss: 0.8952 - val_mean_absolute_error: 0.4036
# Epoch 77/200
#
# Epoch 00077: val_loss did not improve from 0.73709
# 84996/84996 - 384s - loss: 0.6630 - mean_absolute_error: 0.2517 - val_loss: 0.8071 - val_mean_absolute_error: 0.3396
# Epoch 78/200
#
# Epoch 00078: val_loss improved from 0.73709 to 0.70449, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 384s - loss: 0.6592 - mean_absolute_error: 0.2512 - val_loss: 0.7045 - val_mean_absolute_error: 0.2804
# Epoch 79/200
#
# Epoch 00079: val_loss did not improve from 0.70449
# 84996/84996 - 380s - loss: 0.6549 - mean_absolute_error: 0.2501 - val_loss: 0.9311 - val_mean_absolute_error: 0.4168
# Epoch 80/200
#
# Epoch 00080: val_loss did not improve from 0.70449
# 84996/84996 - 379s - loss: 0.6484 - mean_absolute_error: 0.2481 - val_loss: 0.7061 - val_mean_absolute_error: 0.2877
# Epoch 81/200
#
# Epoch 00081: val_loss did not improve from 0.70449
# 84996/84996 - 379s - loss: 0.6460 - mean_absolute_error: 0.2486 - val_loss: 0.7390 - val_mean_absolute_error: 0.3035
# Epoch 82/200
#
# Epoch 00082: val_loss did not improve from 0.70449
# 84996/84996 - 378s - loss: 0.6400 - mean_absolute_error: 0.2465 - val_loss: 0.8394 - val_mean_absolute_error: 0.3777
# Epoch 83/200
#
# Epoch 00083: val_loss did not improve from 0.70449
# 84996/84996 - 378s - loss: 0.6371 - mean_absolute_error: 0.2463 - val_loss: 0.7271 - val_mean_absolute_error: 0.3065
# Epoch 84/200
#
# Epoch 00084: val_loss did not improve from 0.70449
# 84996/84996 - 378s - loss: 0.6310 - mean_absolute_error: 0.2443 - val_loss: 0.8356 - val_mean_absolute_error: 0.3800
# Epoch 85/200
#
# Epoch 00085: val_loss did not improve from 0.70449
# 84996/84996 - 378s - loss: 0.6274 - mean_absolute_error: 0.2438 - val_loss: 0.7100 - val_mean_absolute_error: 0.3012
# Epoch 86/200
#
# Epoch 00086: val_loss did not improve from 0.70449
# 84996/84996 - 378s - loss: 0.6236 - mean_absolute_error: 0.2432 - val_loss: 0.8992 - val_mean_absolute_error: 0.4083
# Epoch 87/200
#
# Epoch 00087: val_loss did not improve from 0.70449
# 84996/84996 - 376s - loss: 0.6184 - mean_absolute_error: 0.2414 - val_loss: 0.7186 - val_mean_absolute_error: 0.3056
# Epoch 88/200
#
# Epoch 00088: val_loss did not improve from 0.70449
# 84996/84996 - 380s - loss: 0.6145 - mean_absolute_error: 0.2406 - val_loss: 0.7134 - val_mean_absolute_error: 0.2999
# Epoch 89/200
#
# Epoch 00089: val_loss improved from 0.70449 to 0.66047, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 380s - loss: 0.6122 - mean_absolute_error: 0.2409 - val_loss: 0.6605 - val_mean_absolute_error: 0.2667
# Epoch 90/200
#
# Epoch 00090: val_loss did not improve from 0.66047
# 84996/84996 - 383s - loss: 0.6079 - mean_absolute_error: 0.2399 - val_loss: 0.7606 - val_mean_absolute_error: 0.3403
# Epoch 91/200
#
# Epoch 00091: val_loss did not improve from 0.66047
# 84996/84996 - 380s - loss: 0.6035 - mean_absolute_error: 0.2386 - val_loss: 0.7833 - val_mean_absolute_error: 0.3596
# Epoch 92/200
#
# Epoch 00092: val_loss did not improve from 0.66047
# 84996/84996 - 378s - loss: 0.5992 - mean_absolute_error: 0.2375 - val_loss: 0.7245 - val_mean_absolute_error: 0.3089
# Epoch 93/200
#
# Epoch 00093: val_loss did not improve from 0.66047
# 84996/84996 - 377s - loss: 0.5956 - mean_absolute_error: 0.2368 - val_loss: 0.7400 - val_mean_absolute_error: 0.3368
# Epoch 94/200
#
# Epoch 00094: val_loss did not improve from 0.66047
# 84996/84996 - 380s - loss: 0.5925 - mean_absolute_error: 0.2364 - val_loss: 0.7099 - val_mean_absolute_error: 0.3010
# Epoch 95/200
#
# Epoch 00095: val_loss improved from 0.66047 to 0.62969, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 380s - loss: 0.5888 - mean_absolute_error: 0.2357 - val_loss: 0.6297 - val_mean_absolute_error: 0.2614
# Epoch 96/200
#
# Epoch 00096: val_loss did not improve from 0.62969
# 84996/84996 - 380s - loss: 0.5854 - mean_absolute_error: 0.2349 - val_loss: 0.6944 - val_mean_absolute_error: 0.2978
# Epoch 97/200
#
# Epoch 00097: val_loss did not improve from 0.62969
# 84996/84996 - 389s - loss: 0.5814 - mean_absolute_error: 0.2340 - val_loss: 0.6637 - val_mean_absolute_error: 0.2817
# Epoch 98/200
#
# Epoch 00098: val_loss did not improve from 0.62969
# 84996/84996 - 385s - loss: 0.5783 - mean_absolute_error: 0.2333 - val_loss: 0.6578 - val_mean_absolute_error: 0.2869
# Epoch 99/200
#
# Epoch 00099: val_loss did not improve from 0.62969
# 84996/84996 - 379s - loss: 0.5743 - mean_absolute_error: 0.2324 - val_loss: 0.7103 - val_mean_absolute_error: 0.3198
# Epoch 100/200
#
# Epoch 00100: val_loss improved from 0.62969 to 0.60611, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 381s - loss: 0.5709 - mean_absolute_error: 0.2318 - val_loss: 0.6061 - val_mean_absolute_error: 0.2520
# Epoch 101/200
#
# Epoch 00101: val_loss did not improve from 0.60611
# 84996/84996 - 380s - loss: 0.5679 - mean_absolute_error: 0.2313 - val_loss: 0.7085 - val_mean_absolute_error: 0.3286
# Epoch 102/200
#
# Epoch 00102: val_loss did not improve from 0.60611
# 84996/84996 - 381s - loss: 0.5638 - mean_absolute_error: 0.2299 - val_loss: 0.6985 - val_mean_absolute_error: 0.3043
# Epoch 103/200
#
# Epoch 00103: val_loss did not improve from 0.60611
# 84996/84996 - 381s - loss: 0.5605 - mean_absolute_error: 0.2292 - val_loss: 0.7158 - val_mean_absolute_error: 0.3219
# Epoch 104/200
#
# Epoch 00104: val_loss did not improve from 0.60611
# 84996/84996 - 381s - loss: 0.5577 - mean_absolute_error: 0.2288 - val_loss: 0.6536 - val_mean_absolute_error: 0.2868
# Epoch 105/200
#
# Epoch 00105: val_loss improved from 0.60611 to 0.60086, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 380s - loss: 0.5543 - mean_absolute_error: 0.2280 - val_loss: 0.6009 - val_mean_absolute_error: 0.2550
# Epoch 106/200
#
# Epoch 00106: val_loss did not improve from 0.60086
# 84996/84996 - 382s - loss: 0.5520 - mean_absolute_error: 0.2280 - val_loss: 0.7488 - val_mean_absolute_error: 0.3528
# Epoch 107/200
#
# Epoch 00107: val_loss did not improve from 0.60086
# 84996/84996 - 380s - loss: 0.5495 - mean_absolute_error: 0.2276 - val_loss: 0.7782 - val_mean_absolute_error: 0.3735
# Epoch 108/200
#
# Epoch 00108: val_loss did not improve from 0.60086
# 84996/84996 - 382s - loss: 0.5452 - mean_absolute_error: 0.2261 - val_loss: 0.7828 - val_mean_absolute_error: 0.3841
# Epoch 109/200
#
# Epoch 00109: val_loss did not improve from 0.60086
# 84996/84996 - 381s - loss: 0.5428 - mean_absolute_error: 0.2258 - val_loss: 0.6528 - val_mean_absolute_error: 0.2962
# Epoch 110/200
#
# Epoch 00110: val_loss did not improve from 0.60086
# 84996/84996 - 380s - loss: 0.5393 - mean_absolute_error: 0.2251 - val_loss: 0.6523 - val_mean_absolute_error: 0.2961
# Epoch 111/200
#
# Epoch 00111: val_loss did not improve from 0.60086
# 84996/84996 - 381s - loss: 0.5372 - mean_absolute_error: 0.2248 - val_loss: 0.6494 - val_mean_absolute_error: 0.2955
# Epoch 112/200
#
# Epoch 00112: val_loss did not improve from 0.60086
# 84996/84996 - 382s - loss: 0.5338 - mean_absolute_error: 0.2238 - val_loss: 0.6664 - val_mean_absolute_error: 0.3004
# Epoch 113/200
#
# Epoch 00113: val_loss improved from 0.60086 to 0.57182, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 380s - loss: 0.5319 - mean_absolute_error: 0.2240 - val_loss: 0.5718 - val_mean_absolute_error: 0.2516
# Epoch 114/200
#
# Epoch 00114: val_loss did not improve from 0.57182
# 84996/84996 - 383s - loss: 0.5286 - mean_absolute_error: 0.2231 - val_loss: 0.6083 - val_mean_absolute_error: 0.2664
# Epoch 115/200
#
# Epoch 00115: val_loss did not improve from 0.57182
# 84996/84996 - 383s - loss: 0.5258 - mean_absolute_error: 0.2225 - val_loss: 0.7051 - val_mean_absolute_error: 0.3463
# Epoch 116/200
#
# Epoch 00116: val_loss did not improve from 0.57182
# 84996/84996 - 379s - loss: 0.5228 - mean_absolute_error: 0.2216 - val_loss: 0.6311 - val_mean_absolute_error: 0.2892
# Epoch 117/200
#
# Epoch 00117: val_loss improved from 0.57182 to 0.53545, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 381s - loss: 0.5206 - mean_absolute_error: 0.2214 - val_loss: 0.5354 - val_mean_absolute_error: 0.2293
# Epoch 118/200
#
# Epoch 00118: val_loss did not improve from 0.53545
# 84996/84996 - 380s - loss: 0.5179 - mean_absolute_error: 0.2209 - val_loss: 0.5375 - val_mean_absolute_error: 0.2339
# Epoch 119/200
#
# Epoch 00119: val_loss did not improve from 0.53545
# 84996/84996 - 382s - loss: 0.5151 - mean_absolute_error: 0.2203 - val_loss: 0.7234 - val_mean_absolute_error: 0.3620
# Epoch 120/200
#
# Epoch 00120: val_loss did not improve from 0.53545
# 84996/84996 - 380s - loss: 0.5127 - mean_absolute_error: 0.2198 - val_loss: 0.5792 - val_mean_absolute_error: 0.2597
# Epoch 121/200
#
# Epoch 00121: val_loss did not improve from 0.53545
# 84996/84996 - 379s - loss: 0.5104 - mean_absolute_error: 0.2195 - val_loss: 0.5807 - val_mean_absolute_error: 0.2596
# Epoch 122/200
#
# Epoch 00122: val_loss did not improve from 0.53545
# 84996/84996 - 380s - loss: 0.5080 - mean_absolute_error: 0.2189 - val_loss: 0.5485 - val_mean_absolute_error: 0.2422
# Epoch 123/200
#
# Epoch 00123: val_loss did not improve from 0.53545
# 84996/84996 - 381s - loss: 0.5052 - mean_absolute_error: 0.2183 - val_loss: 0.6077 - val_mean_absolute_error: 0.2812
# Epoch 124/200
#
# Epoch 00124: val_loss did not improve from 0.53545
# 84996/84996 - 381s - loss: 0.5028 - mean_absolute_error: 0.2179 - val_loss: 0.6075 - val_mean_absolute_error: 0.2861
# Epoch 125/200
# Epoch 00125: val_loss did not improve from 0.53545
# 84996/84996 - 381s - loss: 0.5008 - mean_absolute_error: 0.2176 - val_loss: 0.6519 - val_mean_absolute_error: 0.3214
# Epoch 126/200
#
# Epoch 00126: val_loss did not improve from 0.53545
# 84996/84996 - 381s - loss: 0.4997 - mean_absolute_error: 0.2179 - val_loss: 0.5800 - val_mean_absolute_error: 0.2630
# Epoch 127/200
#
# Epoch 00127: val_loss improved from 0.53545 to 0.53496, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 383s - loss: 0.4957 - mean_absolute_error: 0.2163 - val_loss: 0.5350 - val_mean_absolute_error: 0.2427
# Epoch 128/200
#
# Epoch 00128: val_loss did not improve from 0.53496
# 84996/84996 - 380s - loss: 0.4941 - mean_absolute_error: 0.2163 - val_loss: 0.5866 - val_mean_absolute_error: 0.2773
# Epoch 129/200
#
# Epoch 00129: val_loss did not improve from 0.53496
# 84996/84996 - 380s - loss: 0.4919 - mean_absolute_error: 0.2160 - val_loss: 0.5557 - val_mean_absolute_error: 0.2505
# Epoch 130/200
#
# Epoch 00130: val_loss did not improve from 0.53496
# 84996/84996 - 382s - loss: 0.4892 - mean_absolute_error: 0.2152 - val_loss: 0.5843 - val_mean_absolute_error: 0.2714
# Epoch 131/200
#
# Epoch 00131: val_loss improved from 0.53496 to 0.52589, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 381s - loss: 0.4873 - mean_absolute_error: 0.2149 - val_loss: 0.5259 - val_mean_absolute_error: 0.2374
# Epoch 132/200
#
# Epoch 00132: val_loss improved from 0.52589 to 0.51048, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 381s - loss: 0.4849 - mean_absolute_error: 0.2143 - val_loss: 0.5105 - val_mean_absolute_error: 0.2293
# Epoch 133/200
#
# Epoch 00133: val_loss did not improve from 0.51048
# 84996/84996 - 379s - loss: 0.4842 - mean_absolute_error: 0.2148 - val_loss: 0.5769 - val_mean_absolute_error: 0.2709
# Epoch 134/200
#
# Epoch 00134: val_loss did not improve from 0.51048
# 84996/84996 - 380s - loss: 0.4817 - mean_absolute_error: 0.2141 - val_loss: 0.5822 - val_mean_absolute_error: 0.2694
# Epoch 135/200
#
# Epoch 00135: val_loss improved from 0.51048 to 0.50529, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 379s - loss: 0.4795 - mean_absolute_error: 0.2136 - val_loss: 0.5053 - val_mean_absolute_error: 0.2309
# Epoch 136/200
#
# Epoch 00136: val_loss did not improve from 0.50529
# 84996/84996 - 378s - loss: 0.4770 - mean_absolute_error: 0.2129 - val_loss: 0.5487 - val_mean_absolute_error: 0.2570
# Epoch 137/200
#
# Epoch 00137: val_loss did not improve from 0.50529
# 84996/84996 - 381s - loss: 0.4753 - mean_absolute_error: 0.2129 - val_loss: 0.5354 - val_mean_absolute_error: 0.2446
# Epoch 138/200
#
# Epoch 00138: val_loss did not improve from 0.50529
# 84996/84996 - 382s - loss: 0.4732 - mean_absolute_error: 0.2124 - val_loss: 0.5282 - val_mean_absolute_error: 0.2473
# Epoch 139/200
#
# Epoch 00139: val_loss did not improve from 0.50529
# 84996/84996 - 380s - loss: 0.4716 - mean_absolute_error: 0.2121 - val_loss: 0.5770 - val_mean_absolute_error: 0.2740
# Epoch 140/200
#
# Epoch 00140: val_loss did not improve from 0.50529
# 84996/84996 - 382s - loss: 0.4692 - mean_absolute_error: 0.2114 - val_loss: 0.5409 - val_mean_absolute_error: 0.2519
# Epoch 141/200
#
# Epoch 00141: val_loss improved from 0.50529 to 0.50147, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 380s - loss: 0.4676 - mean_absolute_error: 0.2112 - val_loss: 0.5015 - val_mean_absolute_error: 0.2349
# Epoch 142/200
#
# Epoch 00142: val_loss did not improve from 0.50147
# 84996/84996 - 381s - loss: 0.4655 - mean_absolute_error: 0.2107 - val_loss: 0.5212 - val_mean_absolute_error: 0.2476
# Epoch 143/200
#
# Epoch 00143: val_loss did not improve from 0.50147
# 84996/84996 - 379s - loss: 0.4639 - mean_absolute_error: 0.2105 - val_loss: 0.5247 - val_mean_absolute_error: 0.2508
# Epoch 144/200
#
# Epoch 00144: val_loss did not improve from 0.50147
# 84996/84996 - 379s - loss: 0.4622 - mean_absolute_error: 0.2103 - val_loss: 0.5486 - val_mean_absolute_error: 0.2622
# Epoch 145/200
#
# Epoch 00145: val_loss did not improve from 0.50147
# 84996/84996 - 382s - loss: 0.4599 - mean_absolute_error: 0.2095 - val_loss: 0.5095 - val_mean_absolute_error: 0.2395
# Epoch 146/200
#
# Epoch 00146: val_loss did not improve from 0.50147
# 84996/84996 - 380s - loss: 0.4584 - mean_absolute_error: 0.2094 - val_loss: 0.5334 - val_mean_absolute_error: 0.2566
# Epoch 147/200
#
# Epoch 00147: val_loss improved from 0.50147 to 0.47900, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 379s - loss: 0.4572 - mean_absolute_error: 0.2095 - val_loss: 0.4790 - val_mean_absolute_error: 0.2224
# Epoch 148/200
#
# Epoch 00148: val_loss did not improve from 0.47900
# 84996/84996 - 380s - loss: 0.4550 - mean_absolute_error: 0.2088 - val_loss: 0.5124 - val_mean_absolute_error: 0.2426
# Epoch 149/200
#
# Epoch 00149: val_loss improved from 0.47900 to 0.47779, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 381s - loss: 0.4533 - mean_absolute_error: 0.2085 - val_loss: 0.4778 - val_mean_absolute_error: 0.2227
# Epoch 150/200
#
# Epoch 00150: val_loss did not improve from 0.47779
# 84996/84996 - 380s - loss: 0.4518 - mean_absolute_error: 0.2083 - val_loss: 0.5268 - val_mean_absolute_error: 0.2568
# Epoch 151/200
#
# Epoch 00151: val_loss did not improve from 0.47779
# 84996/84996 - 379s - loss: 0.4509 - mean_absolute_error: 0.2085 - val_loss: 0.4924 - val_mean_absolute_error: 0.2306
# Epoch 152/200
#
# Epoch 00152: val_loss did not improve from 0.47779
# 84996/84996 - 381s - loss: 0.4488 - mean_absolute_error: 0.2079 - val_loss: 0.4836 - val_mean_absolute_error: 0.2271
# Epoch 153/200
#
# Epoch 00153: val_loss improved from 0.47779 to 0.46265, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 381s - loss: 0.4474 - mean_absolute_error: 0.2077 - val_loss: 0.4627 - val_mean_absolute_error: 0.2181
# Epoch 154/200
#
# Epoch 00154: val_loss did not improve from 0.46265
# 84996/84996 - 380s - loss: 0.4457 - mean_absolute_error: 0.2073 - val_loss: 0.5112 - val_mean_absolute_error: 0.2426
# Epoch 155/200
#
# Epoch 00155: val_loss did not improve from 0.46265
# 84996/84996 - 380s - loss: 0.4440 - mean_absolute_error: 0.2070 - val_loss: 0.5151 - val_mean_absolute_error: 0.2563
# Epoch 156/200
#
# Epoch 00156: val_loss did not improve from 0.46265
# 84996/84996 - 380s - loss: 0.4422 - mean_absolute_error: 0.2064 - val_loss: 0.5439 - val_mean_absolute_error: 0.2742
# Epoch 157/200
#
# Epoch 00157: val_loss did not improve from 0.46265
# 84996/84996 - 380s - loss: 0.4409 - mean_absolute_error: 0.2063 - val_loss: 0.5163 - val_mean_absolute_error: 0.2507
# Epoch 158/200
#
# Epoch 00158: val_loss did not improve from 0.46265
# 84996/84996 - 379s - loss: 0.4392 - mean_absolute_error: 0.2060 - val_loss: 0.4803 - val_mean_absolute_error: 0.2292
# Epoch 159/200
#
# Epoch 00159: val_loss did not improve from 0.46265
# 84996/84996 - 380s - loss: 0.4383 - mean_absolute_error: 0.2059 - val_loss: 0.5008 - val_mean_absolute_error: 0.2410
# Epoch 160/200
#
# Epoch 00160: val_loss did not improve from 0.46265
# 84996/84996 - 377s - loss: 0.4370 - mean_absolute_error: 0.2057 - val_loss: 0.4635 - val_mean_absolute_error: 0.2200
# Epoch 161/200
#
# Epoch 00161: val_loss did not improve from 0.46265
# 84996/84996 - 378s - loss: 0.4352 - mean_absolute_error: 0.2054 - val_loss: 0.4995 - val_mean_absolute_error: 0.2454
# Epoch 162/200
#
# Epoch 00162: val_loss did not improve from 0.46265
# 84996/84996 - 377s - loss: 0.4338 - mean_absolute_error: 0.2051 - val_loss: 0.4980 - val_mean_absolute_error: 0.2476
# Epoch 163/200
#
# Epoch 00163: val_loss did not improve from 0.46265
# 84996/84996 - 379s - loss: 0.4329 - mean_absolute_error: 0.2051 - val_loss: 0.4941 - val_mean_absolute_error: 0.2413
# Epoch 164/200
#
# Epoch 00164: val_loss did not improve from 0.46265
# 84996/84996 - 379s - loss: 0.4314 - mean_absolute_error: 0.2048 - val_loss: 0.5234 - val_mean_absolute_error: 0.2634
# Epoch 165/200
#
# Epoch 00165: val_loss improved from 0.46265 to 0.45769, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 379s - loss: 0.4301 - mean_absolute_error: 0.2046 - val_loss: 0.4577 - val_mean_absolute_error: 0.2222
# Epoch 166/200
#
# Epoch 00166: val_loss improved from 0.45769 to 0.45386, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 377s - loss: 0.4288 - mean_absolute_error: 0.2043 - val_loss: 0.4539 - val_mean_absolute_error: 0.2191
# Epoch 167/200
#
# Epoch 00167: val_loss did not improve from 0.45386
# 84996/84996 - 378s - loss: 0.4271 - mean_absolute_error: 0.2037 - val_loss: 0.4667 - val_mean_absolute_error: 0.2291
# Epoch 168/200
#
# Epoch 00168: val_loss did not improve from 0.45386
# 84996/84996 - 378s - loss: 0.4263 - mean_absolute_error: 0.2038 - val_loss: 0.4835 - val_mean_absolute_error: 0.2427
# Epoch 169/200
#
# Epoch 00169: val_loss improved from 0.45386 to 0.43995, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 379s - loss: 0.4246 - mean_absolute_error: 0.2033 - val_loss: 0.4399 - val_mean_absolute_error: 0.2138
# Epoch 170/200
#
# Epoch 00170: val_loss did not improve from 0.43995
# 84996/84996 - 379s - loss: 0.4234 - mean_absolute_error: 0.2032 - val_loss: 0.5009 - val_mean_absolute_error: 0.2552
# Epoch 171/200
#
# Epoch 00171: val_loss did not improve from 0.43995
# 84996/84996 - 381s - loss: 0.4226 - mean_absolute_error: 0.2033 - val_loss: 0.4491 - val_mean_absolute_error: 0.2213
# Epoch 172/200
#
# Epoch 00172: val_loss did not improve from 0.43995
# 84996/84996 - 381s - loss: 0.4212 - mean_absolute_error: 0.2029 - val_loss: 0.4698 - val_mean_absolute_error: 0.2336
# Epoch 173/200
#
# Epoch 00173: val_loss did not improve from 0.43995
# 84996/84996 - 378s - loss: 0.4198 - mean_absolute_error: 0.2025 - val_loss: 0.5038 - val_mean_absolute_error: 0.2599
# Epoch 174/200
#
# Epoch 00174: val_loss did not improve from 0.43995
# 84996/84996 - 377s - loss: 0.4189 - mean_absolute_error: 0.2025 - val_loss: 0.4569 - val_mean_absolute_error: 0.2264
# Epoch 175/200
#
# Epoch 00175: val_loss did not improve from 0.43995
# 84996/84996 - 379s - loss: 0.4177 - mean_absolute_error: 0.2023 - val_loss: 0.4616 - val_mean_absolute_error: 0.2300
# Epoch 176/200
#
# Epoch 00176: val_loss did not improve from 0.43995
# 84996/84996 - 379s - loss: 0.4164 - mean_absolute_error: 0.2020 - val_loss: 0.4475 - val_mean_absolute_error: 0.2218
# Epoch 177/200
#
# Epoch 00177: val_loss did not improve from 0.43995
# 84996/84996 - 379s - loss: 0.4155 - mean_absolute_error: 0.2019 - val_loss: 0.4757 - val_mean_absolute_error: 0.2364
# Epoch 178/200
#
# Epoch 00178: val_loss did not improve from 0.43995
# 84996/84996 - 377s - loss: 0.4140 - mean_absolute_error: 0.2014 - val_loss: 0.4545 - val_mean_absolute_error: 0.2271
# Epoch 179/200
#
# Epoch 00179: val_loss did not improve from 0.43995
# 84996/84996 - 380s - loss: 0.4133 - mean_absolute_error: 0.2016 - val_loss: 0.4940 - val_mean_absolute_error: 0.2552
# Epoch 180/200
#
# Epoch 00180: val_loss did not improve from 0.43995
# 84996/84996 - 378s - loss: 0.4119 - mean_absolute_error: 0.2012 - val_loss: 0.4539 - val_mean_absolute_error: 0.2291
# Epoch 181/200
#
# Epoch 00181: val_loss did not improve from 0.43995
# 84996/84996 - 377s - loss: 0.4109 - mean_absolute_error: 0.2010 - val_loss: 0.4538 - val_mean_absolute_error: 0.2246
# Epoch 182/200
#
# Epoch 00182: val_loss did not improve from 0.43995
# 84996/84996 - 377s - loss: 0.4099 - mean_absolute_error: 0.2008 - val_loss: 0.4659 - val_mean_absolute_error: 0.2334
# Epoch 183/200
#
# Epoch 00183: val_loss did not improve from 0.43995
# 84996/84996 - 377s - loss: 0.4089 - mean_absolute_error: 0.2006 - val_loss: 0.4576 - val_mean_absolute_error: 0.2335
# Epoch 184/200
#
# Epoch 00184: val_loss did not improve from 0.43995
# 84996/84996 - 377s - loss: 0.4077 - mean_absolute_error: 0.2005 - val_loss: 0.4522 - val_mean_absolute_error: 0.2271
# Epoch 185/200
#
# Epoch 00185: val_loss did not improve from 0.43995
# 84996/84996 - 380s - loss: 0.4071 - mean_absolute_error: 0.2005 - val_loss: 0.4403 - val_mean_absolute_error: 0.2208
# Epoch 186/200
#
# Epoch 00186: val_loss did not improve from 0.43995
# 84996/84996 - 380s - loss: 0.4062 - mean_absolute_error: 0.2003 - val_loss: 0.4626 - val_mean_absolute_error: 0.2369
# Epoch 187/200
#
# Epoch 00187: val_loss did not improve from 0.43995
# 84996/84996 - 381s - loss: 0.4050 - mean_absolute_error: 0.2001 - val_loss: 0.4421 - val_mean_absolute_error: 0.2229
# Epoch 188/200
#
# Epoch 00188: val_loss did not improve from 0.43995
# 84996/84996 - 378s - loss: 0.4039 - mean_absolute_error: 0.1998 - val_loss: 0.4738 - val_mean_absolute_error: 0.2450
# Epoch 189/200
#
# Epoch 00189: val_loss improved from 0.43995 to 0.42492, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 378s - loss: 0.4031 - mean_absolute_error: 0.1998 - val_loss: 0.4249 - val_mean_absolute_error: 0.2128
# Epoch 190/200
#
# Epoch 00190: val_loss did not improve from 0.42492
# 84996/84996 - 377s - loss: 0.4021 - mean_absolute_error: 0.1996 - val_loss: 0.4376 - val_mean_absolute_error: 0.2203
# Epoch 191/200
#
# Epoch 00191: val_loss did not improve from 0.42492
# 84996/84996 - 378s - loss: 0.4011 - mean_absolute_error: 0.1993 - val_loss: 0.4341 - val_mean_absolute_error: 0.2219
# Epoch 192/200
#
# Epoch 00192: val_loss did not improve from 0.42492
# 84996/84996 - 379s - loss: 0.4004 - mean_absolute_error: 0.1993 - val_loss: 0.4399 - val_mean_absolute_error: 0.2248
# Epoch 193/200
#
# Epoch 00193: val_loss improved from 0.42492 to 0.42469, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 379s - loss: 0.3991 - mean_absolute_error: 0.1989 - val_loss: 0.4247 - val_mean_absolute_error: 0.2134
# Epoch 194/200
#
# Epoch 00194: val_loss improved from 0.42469 to 0.42184, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 379s - loss: 0.3981 - mean_absolute_error: 0.1987 - val_loss: 0.4218 - val_mean_absolute_error: 0.2135
# Epoch 195/200
#
# Epoch 00195: val_loss did not improve from 0.42184
# 84996/84996 - 380s - loss: 0.3972 - mean_absolute_error: 0.1985 - val_loss: 0.4424 - val_mean_absolute_error: 0.2282
# Epoch 196/200
#
# Epoch 00196: val_loss improved from 0.42184 to 0.41616, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 378s - loss: 0.3967 - mean_absolute_error: 0.1986 - val_loss: 0.4162 - val_mean_absolute_error: 0.2115
# Epoch 197/200
#
# Epoch 00197: val_loss did not improve from 0.41616
# 84996/84996 - 378s - loss: 0.3957 - mean_absolute_error: 0.1983 - val_loss: 0.4465 - val_mean_absolute_error: 0.2297
# Epoch 198/200
#
# Epoch 00198: val_loss improved from 0.41616 to 0.41463, saving model to /home/lab1/repo/planning/traj_pred/veh_models/veh_8kfb2_Feb4.h5
# 84996/84996 - 378s - loss: 0.3949 - mean_absolute_error: 0.1982 - val_loss: 0.4146 - val_mean_absolute_error: 0.2111
# Epoch 199/200
#
# Epoch 00199: val_loss did not improve from 0.41463
# 84996/84996 - 375s - loss: 0.3942 - mean_absolute_error: 0.1982 - val_loss: 0.4312 - val_mean_absolute_error: 0.2209
# Epoch 200/200
#
# Epoch 00200: val_loss did not improve from 0.41463
# 84996/84996 - 379s - loss: 0.3933 - mean_absolute_error: 0.1980 - val_loss: 0.4243 - val_mean_absolute_error: 0.2169

# %%
print("Evaluate on test data")
results = final_model.evaluate(X_test, y_test, batch_size=32)
print("test loss, test acc:", results)


_history_path = home+ '/repo/planning/traj_pred/total_model_history/veh_history_8kfb_Feb4.sav'
pickle.dump(history.history, open(_history_path, 'wb'))

_weights_path =  home+ '/repo/planning/traj_pred/total_model_history/veh_weights_8kfb_Feb4.h5'
final_model.save_weights(_weights_path)
# Out:
# Evaluate on test data
# test loss, test acc: [0.40630614457243486, 0.2049056]

# %%
################################DONE

# %%
# In[ ]:
# X_val, X_test, y_val, y_test,X_train, , y_train,

# %%
history.history.keys()
ax1,=plt.plot( history.history['loss'], c='b', label='Training loss')
ax2,=plt.plot( history.history['val_loss'], c='r', label='Validation loss')

plt.legend(handles=[ax1,ax2])
plt.title('Vehicle model loss')
plt.savefig('vloss')
plt.show()

# %%
# final_model.compile(loss=v3_displacement_error, optimizer=adadelta, metrics=mtrc)
# final_model.load_weights('home+ '/repo/planning/traj_pred/total_model_history/veh_weights.h5'')

# %%
# ##prediction
# # from utilities import get_position_sequence
# def get_position_sequence(prev, new):
#     arr = np.delete(prev, 0, 0)
#     a=np.vstack((arr,new))
#     return a 

# def get_sequence_prediction(X_position_test, i):
#     results =[]
#     s=X_position_test[i]
#     for count in range(0,50):
        
#         result = final_model.predict(np.array([s]))
# #         print(result)
#         results.append(result[0])
#         s = get_position_sequence(s, result)
#     results=np.array(results)
# #     print(s.shape,results.shape)
    
#     return results

# # i= np.random.randint(0, len(X_test))
# # results = get_sequence_prediction(X_test, i)
# # print(results.shape)

# test=np.load('vehicle_test_history.npy')
# v_predict=[]
# print(len(test))
# for i in range(len(test)):
#     print(i)
#     results = get_sequence_prediction(test, i)
#     v_predict.append(results)
# np.save("v_predictions",v_predict)

# print('done')

# %%
# print(np.array(v_predict).shape)
# np.save("v_predictions",v_predict)
# print('done')

# %%
# i= np.random.randint(0, len(X_test))


# # In[ ]:
# # i =2273

# # i=1574
# # i=3070

# # i=387,39
# # i=667
# # i=15
# print("showing trip", i)


# # from utilities import get_position_sequence
# def get_position_sequence(prev, new):
#     arr = np.delete(prev, 0, 0)
#     a=np.vstack((arr,new))
#     return a 

# def get_sequence_prediction(X_position_test, i):
#     results =[]
#     s=X_position_test[i]
#     for count in range(0,12):
        
#         result = final_model.predict(np.array([s]))
# #         print(result)
#         results.append(result[0])
#         s = get_position_sequence(s, result)
#     results=np.array(results)
# #     print(s.shape,results.shape)
    
#     return results

# results = get_sequence_prediction(X_test, i)

# # print(len(results))
# # print("sss",results)

# ax1 =plt.scatter(y_test[i][:,0],y_test[i][:,1],color='b',label='Ground truth')

# ax2 =plt.scatter(X_test[i][:,0],X_test[i][:,1],color='r', label='Training segment')


# ax3 =plt.scatter(results[:,0],results[:,1],color='g', label='Prediction')
# # ax3 =plt.scatter(result[0][0],result[0][1],color='g', label='Prediction')

# plt.legend(handles=[ax1, ax2, ax3])
# plt.show()

# distance = v3_displacement_error(results,y_test[i] )
# avg = K.mean(distance)
# pl =[]
# # tf.print(distance,output_stream=sys.stderr)
# with tf.compat.v1.Session() as sess: pl=distance.eval(), print(distance.eval(),'\naverage',avg.eval()) 
# import matplotlib.pyplot as plt
# # print(pl[0])
# plt.plot(pl[0])
# plt.title('Displacement error')
# plt.show()

# %%
# final_displacement=[]
# avg_displacement=[]

# # for idx in range(0,len(X_test)):
# for idx in range(0,1000):
#     p=[]
#     re= get_sequence_prediction(X_test, idx)
#     distance = v3_displacement_error(re,y_test[idx] )
#     avg = K.mean(distance)
    
#     with tf.compat.v1.Session() as sess:
#         p=distance.eval()
#         ax =avg.eval()
# #     print(p,ax)
#     final_displacement.append(p)
#     avg_displacement.append(ax)

# final_displacement = np.array(final_displacement)
# sec=[]

# for j in range(0,final_displacement.shape[1]):
#     displacement = sum(final_displacement[:,j])/len(final_displacement)
    
#     sec.append(displacement)
# print("Final displacement error:",sec[-1])
# print("Average displacement error:",sum(avg_displacement)/len(avg_displacement))

# print(sec)
# plt.plot(sec)
# plt.title("average displacement error at each timestep")
# plt.show()

# %%
# history2 = pickle.load(open( cwd+ '/saved_model/lab1_txt_max_history_mae_adadelta_600.sav',  "rb") ) 
# history3 = pickle.load(open( cwd+ '/saved_model/lab1_txt_max_history_mae_adadelta.sav',  "rb") )
# print(len(history.history['loss']))
# # plt.plot(range(600,1100),history.history['loss'], c='b')
# # plt.plot( range(300,600), history2['loss'], c='b')
# plt.plot( history3['loss'], c='b')
# plt.title('train loss')

# # plt.plot(range(600,1100),history.history['val_loss'], c='r')
# # plt.plot( range(300,600), history2['val_loss'], c='r')
# plt.plot( history3['val_loss'], c='r')
# plt.title('loss')


# plt.show()
